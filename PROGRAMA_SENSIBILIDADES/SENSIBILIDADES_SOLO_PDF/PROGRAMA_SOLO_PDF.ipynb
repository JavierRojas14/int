# %%
import tabula
import pandas as pd
import numpy as np
import os
import pdfplumber
from datetime import datetime
import json

with open('DICCIONARIO_CODIGO_NOMBRE_FARMACOS.json', 'r', encoding = 'utf-8') as f:
    DICCIONARIO_CODIGO_NOMBRE_FARMACOS = json.load(f)

COLUMNAS_FARMACOS = list(DICCIONARIO_CODIGO_NOMBRE_FARMACOS.values()) + list(map(lambda x: f'CIM {x}', DICCIONARIO_CODIGO_NOMBRE_FARMACOS.values()))
LARGO_COLUMNAS_FARMACOS = len(COLUMNAS_FARMACOS)
COLUMNAS_A_NO_OCUPAR = ['CZA', '?', '? 2', 'CIM CZA', 'CIM ?', 'CIM ? 2']
ANTIBIOGRAMA_VACIO = [None for i in range(LARGO_COLUMNAS_FARMACOS)]

# %%
class ProgramaSensibilidades:
    def __init__(self):
        pass

    def hacer_tabla_global(self):
        todas_las_entradas = self.obtener_entradas_todos_los_pacientes()
        columnas = ['Ingreso', 'Tipo muestra', 'Nº de Cultivo', 'Rut', 'Nombre', 'Servicio', 'Comentario', 'Fecha Firma', 'Microorganismo', 'BLEE'] + COLUMNAS_FARMACOS
        print(len(columnas))
        df = pd.DataFrame(todas_las_entradas, columns = columnas)
        df.drop(columns = COLUMNAS_A_NO_OCUPAR, inplace = True)

        return df

    def obtener_entradas_todos_los_pacientes(self):
        entradas_todos_los_pacientes = []

        for nombre_archivo in os.listdir():
            if '.pdf' in nombre_archivo:
                entradas_de_un_paciente = self.obtener_entradas_de_un_paciente(nombre_archivo)

                for entrada_de_un_paciente in entradas_de_un_paciente:
                    print(f'Entrada de {nombre_archivo}, largo {len(entrada_de_un_paciente)} ')
                    print(entrada_de_un_paciente)
                    entradas_todos_los_pacientes.append(entrada_de_un_paciente)

        return entradas_todos_los_pacientes
    
    def obtener_entradas_de_un_paciente(self, nombre_archivo):
        tipo_archivo, texto_completo_pdf = self.obtener_tipo_de_archivo_y_texto_pdf(nombre_archivo)

        if tipo_archivo != None:
            datos_persona = self.obtener_datos_demograficos_de_un_paciente(texto_completo_pdf)
            lista_microorganismos_persona = self.obtener_microorganismos_de_un_paciente(texto_completo_pdf, tipo_archivo)
            lista_antibiogramas_persona = self.obtener_antibiogramas_de_un_paciente(nombre_archivo, tipo_archivo, len(lista_microorganismos_persona))
            entradas_de_un_paciente_formato_lista = self.formatear_todos_los_datos_un_paciente(datos_persona, lista_microorganismos_persona, lista_antibiogramas_persona)

            return entradas_de_un_paciente_formato_lista
    
    def formatear_todos_los_datos_un_paciente(self, datos_persona, lista_microorganismos_persona, lista_antibiogramas_persona):
        entradas = []
        diccionario_numeracion_cepas = {0: ' I', 1: ' II', 2: ' III', 3: ' IV'}
        for i in range(len(lista_microorganismos_persona)):
            micro = lista_microorganismos_persona[i]
            antibio = lista_antibiogramas_persona[i]

            #antibio[:] = self.cambiar_sensibilidades_enteros_y_staphylos(micro[0], antibio)

            if len(lista_microorganismos_persona) > 1:
                datos_persona_romanos = datos_persona.copy()
                nuevo_numero_cultivo = f'{datos_persona_romanos[2]}{diccionario_numeracion_cepas[i]}'
                datos_persona_romanos[2] = nuevo_numero_cultivo

                entrada_paciente = datos_persona_romanos + micro + antibio
            
            else:
                entrada_paciente = datos_persona + micro + antibio

            
            entradas.append(entrada_paciente)

        return entradas
    
    def obtener_tipo_de_archivo_y_texto_pdf(self, nombre_archivo):
        with pdfplumber.open(nombre_archivo) as pdf:
            texto_completo_pdf = pdf.pages[0].extract_text().split('\n')

            for linea in texto_completo_pdf:
                if 'CULTIVO DE HONGOS' in linea:
                    tipo_archivo = 'HONGOS'
                    break
                
                elif 'Polimicrobiano' in linea:
                    tipo_archivo = 'POLI'
                    break
                
                elif ('HEMOCULTIVO AEROBICO' in linea) or ('HEMOCULTIVO ANAEROBICO' in linea):
                    tipo_archivo = 'NOANTI'
                    break

                elif ('ANTIBIOGRAMA' in linea):
                    tipo_archivo = 'ANTI'
                    break

                else:
                    tipo_archivo = None
    
        return tipo_archivo, texto_completo_pdf

    
    def obtener_datos_demograficos_de_un_paciente(self, texto_completo_pdf):
        datos_personales_relevantes = texto_completo_pdf[3:12]

        nombre_paciente = datos_personales_relevantes[0].split(':')[1][:-10]
        n_orden = datos_personales_relevantes[0].split(':')[-1]
        rut = datos_personales_relevantes[1].split(':')[-1]

        linea_ingreso = datos_personales_relevantes[4].split(' ')
        try:
            fecha_ingreso = datetime.strptime(f'{linea_ingreso[-2]} {linea_ingreso[-1]}', ':%d-%m-%Y %H:%M:%S')
        except ValueError:
            fecha_ingreso = datetime.strptime(f'{linea_ingreso[-2]} {linea_ingreso[-1]}', ':%d/%m/%Y %H:%M:%S')


        linea_firma = datos_personales_relevantes[5].split(' ')
        try:
            fecha_firma = datetime.strptime(f'{linea_firma[-2]} {linea_firma[-1]}', ':%d-%m-%Y %H:%M:%S')
        except ValueError:
            fecha_firma = datetime.strptime(f'{linea_firma[-2]} {linea_firma[-1]}', ':%d/%m/%Y %H:%M:%S')

        seccion = datos_personales_relevantes[5].split(':')[1][:-13]
        tipo_muestra = datos_personales_relevantes[7].split(':')[-1]
        n_cultivo = datos_personales_relevantes[8].split(':', 1)[-1]
        
        for i in range(len(texto_completo_pdf)):
            linea = texto_completo_pdf[i]
            if 'CULTIVO DE HONGOS' in linea:
                n_cultivo = texto_completo_pdf[i + 1].split(' ')[-1]
                break
        
        comentario = None
        for linea in texto_completo_pdf:
            linea = linea.lower()
            if ('avisa' in linea) or ('avisado' in linea):
                comentario = 'ALERTA'
                break
        
        return [fecha_ingreso, tipo_muestra, n_cultivo, rut, nombre_paciente, seccion, comentario, fecha_firma]
    
    def borrador_recuentos_positivos(self, microorganismo):
        a_borrar = ['Rcto:', '+']
        for palabra in a_borrar:
            microorganismo = microorganismo.replace(palabra, '')
            microorganismo = microorganismo.strip()
        
        return microorganismo
    
    def obtener_microorganismos_de_un_paciente(self, texto_pdf, tipo_archivo):
        microorganismos = []

        if tipo_archivo == 'ANTI':
            microorganismos = []
            for linea in texto_pdf:
                if ((('Cepa 1' in linea) or ('Cepa 2' in linea) or ('Cepa 3' in linea) or ('Cepa 4' in linea)) and ('ufc' in linea)):
                    linea_separada = linea.split(' ')
                    for indice, palabra in enumerate(linea_separada):
                        if palabra == '1' or palabra == '2' or palabra == '3' or palabra == '4':
                            indice_inicio_microorganismo = indice + 1
                        
                        elif palabra == 'Mas' or palabra == 'Menos' or '.' in palabra:
                            indice_termino_miccroorganismo = indice
                            break
                        
                    microorganismo = ' '.join(linea_separada[indice_inicio_microorganismo: indice_termino_miccroorganismo])
                    microorganismos.append(microorganismo)
        
        else:
            for linea in texto_pdf:
                if ('CULTIVO DE HONGOS' in linea) or ('HEMOCULTIVO AEROBICO' in linea) or ('HEMOCULTIVO ANAEROBICO' in linea) or ('UROCULTIVO : Polimicrobiano'):
                    microorganismos = list(map(self.borrador_recuentos_positivos, linea.split(':', 1)[-1].split(',')))
        
        microorganismos = list(map(lambda microorg: [microorg, '(+)'] if ('BLEE' in microorg) else [microorg, None], microorganismos))
        return microorganismos
    
    
    def obtener_antibiogramas_de_un_paciente(self, nombre_archivo, tipo_archivo, numero_microorganismos):
        if tipo_archivo == 'ANTI':
            antibiograma_completo = self.obtener_antibiograma_completo(nombre_archivo)
            antibiogramas = self.separar_por_cepa(antibiograma_completo, numero_microorganismos)

        else:
            antibiogramas = [ANTIBIOGRAMA_VACIO for i in range(numero_microorganismos)]
        
        return antibiogramas
    
    def obtener_antibiograma_completo(self, nombre_archivo):
        df = tabula.read_pdf(nombre_archivo, columns = [64, 218, 264, 296, 346, 373, 424, 450, 507], pages = 1, guess = False)[0]
        ya_hay_inicio_antibio = False

        for i in range(len(df)):
            contenido_linea = df.iloc[i].values
            if 'ANTIBIO' in contenido_linea:
                indice_inicio_antibio = i + 1
                ya_hay_inicio_antibio = True
            
            elif not(('ANTIBIO' in  contenido_linea) or ('Cepa 1' in contenido_linea) or ('Sensible' in contenido_linea) or ('Resistente' in contenido_linea) or ('Intermedio' in contenido_linea)) and (ya_hay_inicio_antibio):
                indice_termino_antibio = i
                break

        antibiograma_completo = df.iloc[indice_inicio_antibio: indice_termino_antibio]
        antibiograma_completo.columns = antibiograma_completo.iloc[0]
        antibiograma_completo = antibiograma_completo.iloc[1:, :]
        antibiograma_completo['ANTIBIOTICOS'] = antibiograma_completo['ANTIBIOTICOS'].map(DICCIONARIO_CODIGO_NOMBRE_FARMACOS)
        antibiograma_completo.set_index('ANTIBIOTICOS', inplace = True)
        antibiograma_completo = antibiograma_completo.loc[:, antibiograma_completo.columns.notna()]

        return antibiograma_completo
    
    def separar_por_cepa(self, antibiograma_completo, numero_microorganismos):
        antibiogramas = []

        if antibiograma_completo.empty:
            for i in range(numero_microorganismos):
                antibiogramas.append([None for i in range(LARGO_COLUMNAS_FARMACOS)])
        
        else:
            tablas_cepas = []
            for i in range(int((antibiograma_completo.shape[1]) / 2)):
                df = antibiograma_completo.iloc[:, i * 2: (i * 2) + 2].dropna(how = 'all', axis = 0)
                tablas_cepas.append(df)
            
            cambiador_nomenclatura_sensibilidades = {'Sensible': 'S', 'Resistente': 'R', 'Intermedio': 'I'}
            diccionario_sensibilidades_a_llenar = {farmaco: None for farmaco in DICCIONARIO_CODIGO_NOMBRE_FARMACOS.values()}
            diccionario_cim_a_llenar = {f'CIM {farmaco}': None for farmaco in DICCIONARIO_CODIGO_NOMBRE_FARMACOS.values()}

            for df_cepa in tablas_cepas:
                for farmaco in df_cepa.index:
                    resultado_sensibilidad, cim = df_cepa.loc[farmaco][0], df_cepa.loc[farmaco][1]
                    diccionario_sensibilidades_a_llenar[farmaco] = cambiador_nomenclatura_sensibilidades[resultado_sensibilidad]
                    diccionario_cim_a_llenar[f'CIM {farmaco}'] = cim

                resultados = list((diccionario_sensibilidades_a_llenar | diccionario_cim_a_llenar).values())
                antibiogramas.append(resultados)

        return antibiogramas

# %%
programa = ProgramaSensibilidades()
programa.hacer_tabla_global()
# Out:
# Entrada de 00951237_CAMILA BELEN MUÑOZ SUAZO_HONGOS.pdf, largo 84
# [datetime.datetime(2022, 6, 3, 11, 15, 48), 'Lavado Bronquial', '951237', '20.892.934-8', 'CAMILA BELEN MUÑOZ SUAZO', 'Intermedio Indiferenciado 3', None, datetime.datetime(2022, 6, 6, 11, 25, 21), 'Candida albicans', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ['INSTITUTO NACIONAL DEL TORAX']
# ['SERVICIO DE LABORATORIOS']
# ['25754955', 'Anexo: 254955']
# ['DANIEL REYES DUARTE Nº Orden :00955978']
# ['MASCULINO Rut :13.589.436-2']
# ['42 Años Nº Interno :']
# ['Tipo paciente :Hospitalizado']
# ['Sin especificar Ingreso :23-06-2022 11:51:01']
# ['UCI Fecha Firma :28-06-2022 15:35:56']
# ['Sin especificar Sección :Microbiología']
# ['Tipo muestra :Sangre (Hemocultivo)']
# ['393: I', 'III']
# ['No hubo desarrollo bacteriano a los 5 días de incubación']
# ['P. Izquierdo Hemo III: Arrastre piccline']
# ['Francisca Concha Muga']
# ['Tecnólogo Médico']
# ['FIRMA DIRECTOR TECNICO FIRMA RESPONSABLE']
# Entrada de 00955978_DANIAL REYES DUARTE_NOANTI.pdf, largo 84
# [datetime.datetime(2022, 6, 23, 11, 51, 1), 'Sangre (Hemocultivo)', '393: I, III', '13.589.436-2', 'DANIEL REYES DUARTE', 'UCI', None, datetime.datetime(2022, 6, 28, 15, 35, 56), 'FIRMA DIRECTOR TECNICO FIRMA RESPONSABLE', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Entrada de 00957391_FELIPE JAVIER LEON BELLO_FQ.pdf, largo 84
# [datetime.datetime(2022, 6, 30, 10, 44, 18), 'Lavado Broncoalveolar', '957391 I', '16.742.705-7', 'FELIPE JAVIER LEÓN BELLO', 'BRONCOSCOPIA', 'ALERTA', datetime.datetime(2022, 7, 8, 11, 59, 57), 'Pseudomonas aeruginosa Mucosa', None, 'S', None, 'S', None, 'S', None, None, 'S', None, None, 'S', None, None, None, None, None, 'S', None, 'S', None, 'S', None, None, None, None, 'S', 'S', None, None, 'S', None, None, None, None, None, None, None, nan, None, nan, None, nan, None, None, nan, None, None, nan, None, None, None, None, None, nan, None, nan, None, nan, None, None, None, None, nan, nan, None, None, nan, None, None, None, None, None, None, None]
# Entrada de 00957391_FELIPE JAVIER LEON BELLO_FQ.pdf, largo 84
# [datetime.datetime(2022, 6, 30, 10, 44, 18), 'Lavado Broncoalveolar', '957391 II', '16.742.705-7', 'FELIPE JAVIER LEÓN BELLO', 'BRONCOSCOPIA', 'ALERTA', datetime.datetime(2022, 7, 8, 11, 59, 57), 'Pseudomonas aeruginosa', None, 'I', None, 'R', None, 'R', None, None, 'R', None, None, 'S', None, None, None, None, None, 'S', None, 'R', None, 'R', None, None, None, None, 'R', 'R', None, None, 'S', None, None, None, None, 'S', None, None, '.', None, '.', None, '.', None, None, '.', None, None, '.', None, None, None, None, None, nan, None, '.', None, '.', None, None, None, None, '.', '.', None, None, '.', None, None, None, None, '.', None, None]
# Entrada de 00957643_CLAUDIA ANDREA BASCUÑAN SAAVEDRA.pdf, largo 84
# [datetime.datetime(2022, 7, 1, 9, 30, 1), 'Lavado Bronquial', '957643 I', '12.169.031-4', 'CLAUDIA ANDREA BASCUÑAN SAAVEDRA', 'BRONCOSCOPIA', None, datetime.datetime(2022, 7, 12, 10, 10, 50), 'Klebsiella pneumoniae', None, 'S', None, None, None, 'S', None, None, None, 'S', None, 'S', None, None, None, None, 'S', 'S', None, 'S', None, 'S', None, None, None, 'S', None, 'S', None, None, None, None, None, None, None, None, None, None, '<=8', None, None, None, '<=1', None, None, None, '<=1', None, '<=0,125', None, None, None, None, '<=1', '<=2', None, '<=0,25', None, '<=0,5', None, None, None, '<=4/2', None, '<=4/4', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00957643_CLAUDIA ANDREA BASCUÑAN SAAVEDRA.pdf, largo 84
# [datetime.datetime(2022, 7, 1, 9, 30, 1), 'Lavado Bronquial', '957643 II', '12.169.031-4', 'CLAUDIA ANDREA BASCUÑAN SAAVEDRA', 'BRONCOSCOPIA', None, datetime.datetime(2022, 7, 12, 10, 10, 50), 'Pseudomonas aeruginosa', None, 'S', None, None, None, 'S', None, None, 'S', 'S', None, 'S', None, None, None, None, 'S', 'S', None, 'S', None, 'S', None, None, None, 'S', None, 'S', None, None, None, None, None, None, None, None, None, None, '<=8', None, None, None, '8', None, None, '2', '<=1', None, '<=0,125', None, None, None, None, '<=1', '<=2', None, '1', None, '<=0,5', None, None, None, '<=4/2', None, '<=4/4', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00957643_CLAUDIA ANDREA BASCUÑAN SAAVEDRA.pdf, largo 84
# [datetime.datetime(2022, 7, 1, 9, 30, 1), 'Lavado Bronquial', '957643 III', '12.169.031-4', 'CLAUDIA ANDREA BASCUÑAN SAAVEDRA', 'BRONCOSCOPIA', None, datetime.datetime(2022, 7, 12, 10, 10, 50), 'Pseudomonas aeruginosa', None, 'S', None, 'R', None, 'R', None, None, 'R', 'S', None, 'S', None, None, None, None, 'S', 'S', None, 'S', None, 'S', None, None, None, 'S', 'R', 'R', None, None, None, None, None, None, None, None, None, None, '.', None, '.', None, '.', None, None, '.', '<=1', None, '.', None, None, None, None, '<=1', '.', None, '.', None, '.', None, None, None, '<=4/2', '.', '.', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00959791_JEAN PAOLO PARDO JARA_FQ.pdf, largo 84
# [datetime.datetime(2022, 7, 11, 11, 25, 26), 'Expectoración (M1)', '959791 I', '16.235.862-6', 'JEAN PAOLO PARDO JARA', 'POLICLINICO', 'ALERTA', datetime.datetime(2022, 7, 20, 10, 1, 17), 'Klebsiella variicola', None, 'S', None, None, None, 'S', None, None, None, 'S', None, 'R', None, None, None, None, 'S', 'S', None, 'S', None, 'S', None, None, None, 'S', None, 'S', None, None, None, None, None, None, None, None, None, None, '<=8', None, None, None, '<=1', None, None, None, '<=1', None, '2', None, None, None, None, '<=0,25', '<=2', None, '0,5', None, nan, None, None, None, '<=4/2', None, '<=4/4', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00959791_JEAN PAOLO PARDO JARA_FQ.pdf, largo 84
# [datetime.datetime(2022, 7, 11, 11, 25, 26), 'Expectoración (M1)', '959791 II', '16.235.862-6', 'JEAN PAOLO PARDO JARA', 'POLICLINICO', 'ALERTA', datetime.datetime(2022, 7, 20, 10, 1, 17), 'Pseudomonas aeruginosa', None, 'S', None, 'S', None, 'R', None, None, 'R', 'S', None, 'S', None, None, None, None, 'S', 'R', None, 'S', None, 'S', None, None, None, 'S', None, 'S', None, None, 'S', None, None, None, None, None, None, None, '16', None, '.', None, '>16', None, None, '>16', '<=1', None, '0,5', None, None, None, None, '<=0,25', '>8', None, '2', None, '.', None, None, None, '<=4/2', None, '16/4', None, None, '.', None, None, None, None, None, None, None]
# Entrada de 00959791_JEAN PAOLO PARDO JARA_FQ.pdf, largo 84
# [datetime.datetime(2022, 7, 11, 11, 25, 26), 'Expectoración (M1)', '959791 III', '16.235.862-6', 'JEAN PAOLO PARDO JARA', 'POLICLINICO', 'ALERTA', datetime.datetime(2022, 7, 20, 10, 1, 17), 'Pseudomonas aeruginosa', None, 'S', None, 'S', None, 'S', None, None, 'S', 'S', None, 'S', None, None, None, None, 'S', 'S', None, 'S', None, 'S', None, None, None, 'S', None, 'S', None, None, 'R', None, None, None, None, None, None, None, '<=8', None, '.', None, '4', None, None, '2', '<=1', None, '0,25', None, None, None, None, '<=0,25', '<=2', None, '2', None, '<=0,5', None, None, None, '<=4/2', None, '<=4/4', None, None, '.', None, None, None, None, None, None, None]
# Entrada de 00959791_JEAN PAOLO PARDO JARA_FQ.pdf, largo 84
# [datetime.datetime(2022, 7, 11, 11, 25, 26), 'Expectoración (M1)', '959791 IV', '16.235.862-6', 'JEAN PAOLO PARDO JARA', 'POLICLINICO', 'ALERTA', datetime.datetime(2022, 7, 20, 10, 1, 17), 'Pseudomonas aeruginosa', None, 'S', None, 'S', None, 'S', None, None, 'S', 'S', None, 'S', None, None, None, None, 'S', 'I', None, 'R', None, 'I', None, None, None, 'S', None, 'S', None, None, 'S', None, None, None, None, None, None, None, '<=8', None, '.', None, '4', None, None, '8', '<=1', None, '0,25', None, None, None, None, '<=0,25', '8', None, '>8', None, '4', None, None, None, '<=4/2', None, '<=4/4', None, None, '.', None, None, None, None, None, None, None]
# ['INSTITUTO NACIONAL DEL TORAX']
# ['SERVICIO DE LABORATORIOS']
# ['25754955', 'Anexo: 254955']
# ['JEAN PAOLO PARDO JARA Nº Orden :00959791']
# ['MASCULINO Rut :16.235.862-6']
# ['34 Años Tipo paciente :Ambulatorio']
# ['952156934 Nº Interno :']
# ['Sin especificar Ingreso :11-07-2022 11:25:26']
# ['POLICLINICO Firma exámen :15-07-2022 11:07:37']
# ['Sin especificar Sección :BACTERIOLOGIA']
# ['Sin especificar Muestra :Expectoración (M1)']
# ['EXAMENES']
# ['TEST RESULTADO UNIDAD MEDIDA VALOR DE REFERENCIA']
# ['Rcto : Candida albicans']
# ['733']
# ['Francisca Concha Muga']
# ['Tecnólogo Médico']
# ['FIRMA DIRECTOR TECNICO Francisca Concha Muga']
# Entrada de 00959791_JEAN PAOLO PARDO JARA_HONGOS.pdf, largo 84
# [datetime.datetime(2022, 7, 11, 11, 25, 26), 'Expectoración (M1)', '733', '16.235.862-6', 'JEAN PAOLO PARDO JARA', 'POLICLINICO ', None, datetime.datetime(2022, 7, 15, 11, 7, 37), 'FIRMA DIRECTOR TECNICO Francisca Concha Muga', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Entrada de 00960921_ISABEL DE LOS ANGELES PEÑA ARDILES.pdf, largo 84
# [datetime.datetime(2022, 7, 15, 12, 17, 44), 'Expectoración (M1)', '960921 I', '7.381.552-5', 'ISABEL DE LOS ANGELES PEÑA ARDILES', 'POLICLINICO', None, datetime.datetime(2022, 7, 27, 9, 27, 27), 'Pseudomonas aeruginosa', None, 'R', None, None, None, 'R', None, None, 'S', None, None, 'R', None, None, None, None, None, 'R', None, 'S', None, 'S', None, None, None, None, None, 'R', None, None, None, None, None, None, None, None, None, None, '>32', None, None, None, '>16', None, None, '4', None, None, '>2', None, None, None, None, None, '>8', None, '<=0,25', None, '2', None, None, None, None, None, '>64/4', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00960921_ISABEL DE LOS ANGELES PEÑA ARDILES.pdf, largo 84
# [datetime.datetime(2022, 7, 15, 12, 17, 44), 'Expectoración (M1)', '960921 II', '7.381.552-5', 'ISABEL DE LOS ANGELES PEÑA ARDILES', 'POLICLINICO', None, datetime.datetime(2022, 7, 27, 9, 27, 27), 'Pseudomonas aeruginosa', None, 'S', None, None, None, 'S', None, None, 'S', None, None, 'S', None, None, None, None, None, 'S', None, 'S', None, 'S', None, None, None, None, None, 'S', None, None, None, None, None, None, None, None, None, None, '<=8', None, None, None, '2', None, None, '8', None, None, '0,5', None, None, None, None, None, '<=2', None, '0,5', None, '2', None, None, None, None, None, '<=4/4', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00960921_ISABEL DE LOS ANGELES PEÑA ARDILES.pdf, largo 84
# [datetime.datetime(2022, 7, 15, 12, 17, 44), 'Expectoración (M1)', '960921 III', '7.381.552-5', 'ISABEL DE LOS ANGELES PEÑA ARDILES', 'POLICLINICO', None, datetime.datetime(2022, 7, 27, 9, 27, 27), 'Pseudomonas aeruginosa Mucosa', None, 'S', None, 'R', None, 'R', None, None, 'R', None, None, 'S', None, None, None, None, None, 'R', None, 'S', None, 'S', None, None, None, None, 'R', 'R', None, None, None, None, None, None, None, None, None, None, '.', None, '.', None, '.', None, None, '.', None, None, '.', None, None, None, None, None, '.', None, '.', None, '.', None, None, None, None, '.', '.', None, None, None, None, None, None, None, None, None, None]
# ['INSTITUTO NACIONAL DEL TORAX']
# ['SERVICIO DE LABORATORIOS']
# ['25754955', 'Anexo: 254955']
# ['QUINTIN FERNANDO RIQUELME ESPINOZA Nº Orden :00961451']
# ['MASCULINO Rut :6.003.178-9']
# ['69 Años Nº Interno :']
# ['934121626 Tipo paciente :Hospitalizado']
# ['Sin especificar Ingreso :18-07-2022 23:21:28']
# ['Servicio Médico Quirúrgico Respiratorio Norte Fecha Firma :20-07-2022 09:42:47']
# ['Sin especificar Sección :Microbiología']
# ['Tipo muestra :UROCULTIVO']
# ['961451']
# ['UROCULTIVO']
# ['Polimicrobiano']
# ['Se solicita nueva muestra']
# ['Francisca Concha Muga']
# ['Tecnólogo Médico']
# ['FIRMA DIRECTOR TECNICO FIRMA RESPONSABLE']
# Entrada de 00961451_QUINTIN FERNANDO RIQUELME ESPINOZA_POLI.pdf, largo 84
# [datetime.datetime(2022, 7, 18, 23, 21, 28), 'UROCULTIVO', '961451', '6.003.178-9', 'QUINTIN FERNANDO RIQUELME ESPINOZA', 'Servicio Médico Quirúrgico Respiratorio Norte', None, datetime.datetime(2022, 7, 20, 9, 42, 47), 'FIRMA DIRECTOR TECNICO FIRMA RESPONSABLE', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Entrada de 00963294_MARIA MAGDALENA ESPINOZA ECHANES.pdf, largo 84
# [datetime.datetime(2022, 7, 27, 10, 0, 39), 'Expectoración (M1)', '963294', '9.197.116-K', 'MARIA MAGDALENA ESPINOZA ECHANES', 'POLICLINICO', None, datetime.datetime(2022, 7, 29, 10, 44, 12), 'Klebsiella pneumoniae', None, 'S', None, None, None, 'S', None, None, None, 'S', None, 'S', None, None, None, None, 'S', 'S', None, 'S', None, 'S', None, None, None, 'S', None, 'S', None, None, None, None, None, None, None, None, None, None, '<=8', None, None, None, '<=1', None, None, None, '<=1', None, '<=0,125', None, None, None, None, '<=0,25', '<=2', None, '<=0,25', None, '<=0,5', None, None, None, '8/4', None, '<=4/4', None, None, None, None, None, None, None, None, None, None]
# Entrada de 00963464_MARISOL DEL CARMEN ARENAS CANO.pdf, largo 84
# [datetime.datetime(2022, 7, 27, 22, 6, 45), 'UROCULTIVO', '963464', '17.983.418-9', 'MARISOL DEL CARMEN ARENAS CANO', 'Servicio Médico Quirúrgico Respiratorio Norte', None, datetime.datetime(2022, 7, 29, 11, 10, 42), 'Candida albicans', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 84
#                Ingreso           Tipo muestra Nº de Cultivo           Rut  \
# 0  2022-06-03 11:15:48       Lavado Bronquial        951237  20.892.934-8
# 1  2022-06-23 11:51:01   Sangre (Hemocultivo)   393: I, III  13.589.436-2
# 2  2022-06-30 10:44:18  Lavado Broncoalveolar      957391 I  16.742.705-7
# 3  2022-06-30 10:44:18  Lavado Broncoalveolar     957391 II  16.742.705-7
# 4  2022-07-01 09:30:01       Lavado Bronquial      957643 I  12.169.031-4
# 5  2022-07-01 09:30:01       Lavado Bronquial     957643 II  12.169.031-4
# 6  2022-07-01 09:30:01       Lavado Bronquial    957643 III  12.169.031-4
# 7  2022-07-11 11:25:26     Expectoración (M1)      959791 I  16.235.862-6
# 8  2022-07-11 11:25:26     Expectoración (M1)     959791 II  16.235.862-6
# 9  2022-07-11 11:25:26     Expectoración (M1)    959791 III  16.235.862-6
# 10 2022-07-11 11:25:26     Expectoración (M1)     959791 IV  16.235.862-6
# 11 2022-07-11 11:25:26     Expectoración (M1)           733  16.235.862-6
# 12 2022-07-15 12:17:44     Expectoración (M1)      960921 I   7.381.552-5
# 13 2022-07-15 12:17:44     Expectoración (M1)     960921 II   7.381.552-5
# 14 2022-07-15 12:17:44     Expectoración (M1)    960921 III   7.381.552-5
# 15 2022-07-18 23:21:28             UROCULTIVO        961451   6.003.178-9
# 16 2022-07-27 10:00:39     Expectoración (M1)        963294   9.197.116-K
# 17 2022-07-27 22:06:45             UROCULTIVO        963464  17.983.418-9
#
#                                 Nombre  \
# 0             CAMILA BELEN MUÑOZ SUAZO
# 1                  DANIEL REYES DUARTE
# 2             FELIPE JAVIER LEÓN BELLO
# 3             FELIPE JAVIER LEÓN BELLO
# 4     CLAUDIA ANDREA BASCUÑAN SAAVEDRA
# 5     CLAUDIA ANDREA BASCUÑAN SAAVEDRA
# 6     CLAUDIA ANDREA BASCUÑAN SAAVEDRA
# 7                JEAN PAOLO PARDO JARA
# 8                JEAN PAOLO PARDO JARA
# 9                JEAN PAOLO PARDO JARA
# 10               JEAN PAOLO PARDO JARA
# 11               JEAN PAOLO PARDO JARA
# 12  ISABEL DE LOS ANGELES PEÑA ARDILES
# 13  ISABEL DE LOS ANGELES PEÑA ARDILES
# 14  ISABEL DE LOS ANGELES PEÑA ARDILES
# 15  QUINTIN FERNANDO RIQUELME ESPINOZA
# 16    MARIA MAGDALENA ESPINOZA ECHANES
# 17      MARISOL DEL CARMEN ARENAS CANO
#
#                                          Servicio Comentario  \
# 0                     Intermedio Indiferenciado 3       None
# 1                                             UCI       None
# 2                                    BRONCOSCOPIA     ALERTA
# 3                                    BRONCOSCOPIA     ALERTA
# 4                                    BRONCOSCOPIA       None
# 5                                    BRONCOSCOPIA       None
# 6                                    BRONCOSCOPIA       None
# 7                                     POLICLINICO     ALERTA
# 8                                     POLICLINICO     ALERTA
# 9                                     POLICLINICO     ALERTA
# 10                                    POLICLINICO     ALERTA
# 11                                   POLICLINICO        None
# 12                                    POLICLINICO       None
# 13                                    POLICLINICO       None
# 14                                    POLICLINICO       None
# 15  Servicio Médico Quirúrgico Respiratorio Norte       None
# 16                                    POLICLINICO       None
# 17  Servicio Médico Quirúrgico Respiratorio Norte       None
#
#            Fecha Firma                                Microorganismo  BLEE  \
# 0  2022-06-06 11:25:21                              Candida albicans  None
# 1  2022-06-28 15:35:56      FIRMA DIRECTOR TECNICO FIRMA RESPONSABLE  None
# 2  2022-07-08 11:59:57                 Pseudomonas aeruginosa Mucosa  None
# 3  2022-07-08 11:59:57                        Pseudomonas aeruginosa  None
# 4  2022-07-12 10:10:50                         Klebsiella pneumoniae  None
# 5  2022-07-12 10:10:50                        Pseudomonas aeruginosa  None
# 6  2022-07-12 10:10:50                        Pseudomonas aeruginosa  None
# 7  2022-07-20 10:01:17                          Klebsiella variicola  None
# 8  2022-07-20 10:01:17                        Pseudomonas aeruginosa  None
# 9  2022-07-20 10:01:17                        Pseudomonas aeruginosa  None
# 10 2022-07-20 10:01:17                        Pseudomonas aeruginosa  None
# 11 2022-07-15 11:07:37  FIRMA DIRECTOR TECNICO Francisca Concha Muga  None
# 12 2022-07-27 09:27:27                        Pseudomonas aeruginosa  None
# 13 2022-07-27 09:27:27                        Pseudomonas aeruginosa  None
# 14 2022-07-27 09:27:27                 Pseudomonas aeruginosa Mucosa  None
# 15 2022-07-20 09:42:47      FIRMA DIRECTOR TECNICO FIRMA RESPONSABLE  None
# 16 2022-07-29 10:44:12                         Klebsiella pneumoniae  None
# 17 2022-07-29 11:10:42                              Candida albicans  None
#
#     ... CIM SAM CIM SP CIM TAZO CIM TEICO CIM TGC CIM TOB CIM LEVO CIM MINO  \
# 0   ...    None   None     None      None    None    None     None     None
# 1   ...    None   None     None      None    None    None     None     None
# 2   ...    None    NaN      NaN      None    None     NaN     None     None
# 3   ...    None      .        .      None    None       .     None     None
# 4   ...   <=4/2   None    <=4/4      None    None    None     None     None
# 5   ...   <=4/2   None    <=4/4      None    None    None     None     None
# 6   ...   <=4/2      .        .      None    None    None     None     None
# 7   ...   <=4/2   None    <=4/4      None    None    None     None     None
# 8   ...   <=4/2   None     16/4      None    None       .     None     None
# 9   ...   <=4/2   None    <=4/4      None    None       .     None     None
# 10  ...   <=4/2   None    <=4/4      None    None       .     None     None
# 11  ...    None   None     None      None    None    None     None     None
# 12  ...    None   None    >64/4      None    None    None     None     None
# 13  ...    None   None    <=4/4      None    None    None     None     None
# 14  ...    None      .        .      None    None    None     None     None
# 15  ...    None   None     None      None    None    None     None     None
# 16  ...     8/4   None    <=4/4      None    None    None     None     None
# 17  ...    None   None     None      None    None    None     None     None
#
#    CIM DAP CIM VAN
# 0     None    None
# 1     None    None
# 2     None    None
# 3     None    None
# 4     None    None
# 5     None    None
# 6     None    None
# 7     None    None
# 8     None    None
# 9     None    None
# 10    None    None
# 11    None    None
# 12    None    None
# 13    None    None
# 14    None    None
# 15    None    None
# 16    None    None
# 17    None    None
#
# [18 rows x 78 columns]
