# %%
import pandas as pd
import os

# %%
dfs = [pd.read_excel(x) for x in os.listdir() if '.xlsx' in x]

# %%
sii_completo = pd.concat(dfs)

# %%
sii_completo.to_excel('SII 2019-2021.xlsx')

# %%
sii_completo
# Out:
#        Unnamed: 0   Nro  Tipo Doc Tipo Compra RUT Proveedor  \
# 0               0     1        33    Del Giro    76116604-2
# 1               1     2        33    Del Giro    76610462-2
# 2               2     3        61    Del Giro    76116604-2
# 3               0     1        33    Del Giro    76610462-2
# 4               1     2        33    Del Giro    77461630-6
# ...           ...   ...       ...         ...           ...
# 14324        1180  1181        61    Del Giro    76695020-5
# 14325        1181  1182        61    Del Giro    76215260-6
# 14326        1182  1183        61    Del Giro    84609600-0
# 14327        1183  1184        61    Del Giro    77596940-7
# 14328        1184  1185        61    Del Giro    96756540-7
#
#                                             Razon Social  Folio Fecha Docto  \
# 0                       Importadora y Comercializadora B  10023  08-07-2019
# 1                     COMERCIAL E IMPORTADORA MEYDAN SPA    247  10-07-2019
# ...
