# %%
import pandas as pd
import os

# %%
dfs = [pd.read_excel(x) for x in os.listdir() if '.xlsx' in x]

# %%
sii_completo = pd.concat(dfs)

# %%
sii_completo.to_excel('SII 2019-2022.xlsx', index = False)

# %%
sii_completo
# Out:
#        Unnamed: 0   Nro  Tipo Doc Tipo Compra RUT Proveedor  \
# 0             0.0     1        33    Del Giro    76116604-2
# 1             1.0     2        33    Del Giro    76610462-2
# 2             2.0     3        61    Del Giro    76116604-2
# 3             0.0     1        33    Del Giro    76610462-2
# 4             1.0     2        33    Del Giro    77461630-6
# ...           ...   ...       ...         ...           ...
# 10555         NaN  1043        61    Del Giro    59051480-2
# 10556         NaN  1044        61    Del Giro    96689310-9
# 10557         NaN  1045        61    Del Giro    59043540-6
# 10558         NaN  1046        61    Del Giro    96669540-4
# 10559         NaN  1047        61    Del Giro    96669540-4
#
#                              Razon Social    Folio Fecha Docto  \
# 0        Importadora y Comercializadora B    10023  08-07-2019
# 1      COMERCIAL E IMPORTADORA MEYDAN SPA      247  10-07-2019
# 2        Importadora y Comercializadora B      727  09-07-2019
# 3      COMERCIAL E IMPORTADORA MEYDAN SPA      280  29/08/2019
# 4             CORP MEDICAL CHILE LIMITADA     3887  29/08/2019
# ...                                   ...      ...         ...
# 10555           Becton Dickinson de Chile    11305  26-07-2022
# 10556                      TRANSBANK S.A.  5461953  26-07-2022
# 10557      MERCK SHARP  DOHME (I A) CORP.    21064  27-07-2022
# 10558                     INTERGRADE S.A.     3631  28-07-2022
# 10559                     INTERGRADE S.A.     3635  28-07-2022
#
#            Fecha Recepcion        Fecha Reclamo  ...  Monto Neto Activo Fijo  \
# 0         08-07-2019 10:40     12-07-2019 11:42  ...                     NaN
# 1          10-07-2019 9:16     17-07-2019 16:23  ...                     NaN
# 2         09-07-2019 13:34     12-07-2019 11:42  ...                     NaN
# 3      29/08/2019 09:43:21  05/09/2019 10:39:32  ...                     NaN
# 4      29/08/2019 12:55:46  05/09/2019 13:29:51  ...                     NaN
# ...                    ...                  ...  ...                     ...
# 10555     26-07-2022 17:09                  NaN  ...                     NaN
# 10556     26-07-2022 20:21                  NaN  ...                     NaN
# 10557     27-07-2022 17:44                  NaN  ...                     NaN
# 10558     28-07-2022 13:21                  NaN  ...                     NaN
# 10559     28-07-2022 20:41                  NaN  ...                     NaN
#
#        IVA Activo Fijo  IVA uso Comun  Impto. Sin Derecho a Credito  \
# 0                  NaN            NaN                           NaN
# 1                  NaN            NaN                           NaN
# 2                  NaN            NaN                           NaN
# 3                  NaN            NaN                           NaN
# 4                  NaN            NaN                           NaN
# ...                ...            ...                           ...
# 10555              NaN            NaN                           NaN
# 10556              NaN            NaN                           NaN
# 10557              NaN            NaN                           NaN
# 10558              NaN            NaN                           NaN
# 10559              NaN            NaN                           NaN
#
#        IVA No Retenido  NCE o NDE sobre Fact. de Compra  Codigo Otro Impuesto  \
# 0                    0                                0                   NaN
# 1                    0                                0                   NaN
# 2                    0                                0                   NaN
# 3                    0                                0                   NaN
# 4                    0                                0                   NaN
# ...                ...                              ...                   ...
# 10555                0                                0                   NaN
# 10556                0                                0                   NaN
# 10557                0                                0                   NaN
# 10558                0                                0                   NaN
# 10559                0                                0                   NaN
#
#        Valor Otro Impuesto  Tasa Otro Impuesto  Fecha Acuse
# 0                      NaN                 NaN          NaN
# 1                      NaN                 NaN          NaN
# 2                      NaN                 NaN          NaN
# 3                      NaN                 NaN          NaN
# 4                      NaN                 NaN          NaN
# ...                    ...                 ...          ...
# 10555                  NaN                 NaN          NaN
# 10556                  NaN                 NaN          NaN
# 10557                  NaN                 NaN          NaN
# 10558                  NaN                 NaN          NaN
# 10559                  NaN                 NaN          NaN
#
# [51229 rows x 26 columns]
