# %%
import pandas as pd
import os

# %%
dfs = [pd.read_excel(x, header = 10) for x in os.listdir() if '.xlsx' in x]

# %%
sigfe_completo = pd.concat(dfs)

# %%
sigfe_completo.to_excel('Sigfe_2019-2022.xlsx')

# %%
sigfe_completo
# Out:
#                                          Cuenta Contable  \
# 0      21522 Cuentas por Pagar - Bienes y Servicios d...
# 1      21522 Cuentas por Pagar - Bienes y Servicios d...
# 2      21522 Cuentas por Pagar - Bienes y Servicios d...
# 3      21522 Cuentas por Pagar - Bienes y Servicios d...
# 4      21522 Cuentas por Pagar - Bienes y Servicios d...
# ...                                                  ...
# 15781  21522 Cuentas por Pagar - Bienes y Servicios d...
# 15782  21522 Cuentas por Pagar - Bienes y Servicios d...
# 15783  21522 Cuentas por Pagar - Bienes y Servicios d...
# 15784  21522 Cuentas por Pagar - Bienes y Servicios d...
# 15785  21522 Cuentas por Pagar - Bienes y Servicios d...
#
#                                          Principal  Saldo Tipo Movimiento  \
# 0           10371417-6 JOSE ENRIQUE ANDUEZA GATICA    0.0      Tipo Flujo
# 1           10371417-6 JOSE ENRIQUE ANDUEZA GATICA    0.0      Tipo Flujo
# ...
