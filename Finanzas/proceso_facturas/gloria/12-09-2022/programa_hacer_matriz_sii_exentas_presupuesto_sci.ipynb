# %%
import pandas as pd
import datetime
import os
pd.options.mode.chained_assignment = None  # default='warn'

# %%
class GeneradorPlanillaFinanzas:
    def __init__(self):
        pass

    def correr_programa(self):
        diccionario_dfs = self.identificar_tipo_de_archivo_y_cargar_dfs()
        dfs_limpias = self.limpiar_dfs(diccionario_dfs)
        df_completa, df_columnas_utiles = self.unir_dfs(dfs_limpias)

        self.guardar_dfs(df_completa, df_columnas_utiles)
    
    def identificar_tipo_de_archivo_y_cargar_dfs(self):
        identificadores_archivo = {'33': 'SII FACTURAS ELECTRONICAS/EXENTAS/NC', 
                                 '34': 'SII FACTURAS ELECTRONICAS/EXENTAS/NC', 
                                 '61': 'SII FACTURAS ELECTRONICAS/EXENTAS/NC',
                                 'reporte': 'ACEPTA',
                                 'presupuesto': 'PRESUPUESTO',
                                 'Documentos recepcion': 'SCI',
                                 'SA_Cartera': 'SIGFE'}

        llaves_identificadoras = list(identificadores_archivo.keys())
                
        diccionario_dfs = {'SII FACTURAS ELECTRONICAS/EXENTAS/NC': None,
                           'ACEPTA': None, 
                           'PRESUPUESTO': None, 
                           'SCI': None,
                           'SIGFE': None}

        for nombre_archivo in os.listdir('input'):
            nombre_archivo = os.path.join('input', nombre_archivo)
            if ('.xlsx' in nombre_archivo) or ('.xls' in nombre_archivo) or ('.csv' in nombre_archivo):
                for llave in llaves_identificadoras:
                    if llave in nombre_archivo:
                        identificador_archivo = identificadores_archivo[llave]
                        print(f'Leyendo {nombre_archivo}, es del tipo: {identificador_archivo}')
                        if llave == '33':
                            diccionario_dfs[identificador_archivo] = pd.read_csv(nombre_archivo, delimiter = ';')
    
                        elif llave == '34' or llave == '61':
                            df_arriba = diccionario_dfs[identificador_archivo]
                            df_abajo = pd.read_csv(nombre_archivo, delimiter = ';')
                            diccionario_dfs[identificador_archivo] = pd.concat([df_arriba, df_abajo])
                        
                        elif llave == 'SA_Cartera':
                            df = pd.read_excel(nombre_archivo, header = 10)
                            df['RUT Emisor'] = df['Principal'].apply(lambda x: x.split(' ')[0])
                            diccionario_dfs[identificador_archivo] = df
                        
                        else:
                            diccionario_dfs[identificador_archivo] = pd.read_excel(nombre_archivo)
                        
                        break

        return diccionario_dfs
    
    # Solo se limpian las que no son del SII.    
    def limpiar_dfs(self, diccionario_dfs):
        for nombre_tabla, df in diccionario_dfs.items():
            if nombre_tabla == 'ACEPTA':
                df.rename(columns = {'emisor': 'RUT Emisor', 'folio': 'Folio'}, inplace = True)
            
            elif nombre_tabla == 'PRESUPUESTO':
                df.rename(columns = {'Rut': 'RUT Emisor', 'Folio': 'Folio_abreviado', 'NºDoc.': 'Folio'}, inplace = True)

            elif nombre_tabla == 'SCI':
                df.rename(columns = {'Rut Proveedor': 'RUT Emisor', 'Numero Documento': 'Folio'}, inplace = True)
            
            elif nombre_tabla == 'SIGFE':
                df.rename(columns = {'Folio': 'Folio_abreviado', 'Número ': 'Folio'}, inplace = True)
            
            print(df.columns)
            
            df['RUT Emisor'] = df['RUT Emisor'].apply(lambda x: x.replace('.', ''))
            
            df.columns = df.columns + f' {nombre_tabla}'

            df[f'RUT Emisor {nombre_tabla}'] = df[f'RUT Emisor {nombre_tabla}'].apply(lambda rut: rut.replace('.', '').upper().strip())

            df['llave_id'] = df[f'RUT Emisor {nombre_tabla}'] + df[f'Folio {nombre_tabla}'].astype(str)
            df.set_index('llave_id', drop = True, inplace = True)

        return diccionario_dfs
    
    def unir_dfs(self, diccionario_dfs_limpias):
        lista_dfs_secuenciales = list(diccionario_dfs_limpias.values())
        df_izquierda = lista_dfs_secuenciales[0]

        for df_derecha in lista_dfs_secuenciales[1:]:
            df_izquierda = pd.merge(df_izquierda, df_derecha, how = 'left', left_index = True, right_index = True)
        
        df_izquierda = df_izquierda[~df_izquierda.index.duplicated(keep = 'first')]

        df_izquierda['Fecha Docto. SII FACTURAS ELECTRONICAS/EXENTAS/NC'] = pd.to_datetime(df_izquierda['Fecha Docto. SII FACTURAS ELECTRONICAS/EXENTAS/NC'], dayfirst = True)
        df_izquierda['Fecha Recep. SII FACTURAS ELECTRONICAS/EXENTAS/NC'] = pd.to_datetime(df_izquierda['Fecha Recep. SII FACTURAS ELECTRONICAS/EXENTAS/NC'], dayfirst = True)
        df_izquierda['tiempo_diferencia'] = pd.to_datetime('today') - df_izquierda['Fecha Docto. SII FACTURAS ELECTRONICAS/EXENTAS/NC']
        df_izquierda['esta_al_dia'] = df_izquierda['tiempo_diferencia'] <= datetime.timedelta(8)

        columnas_a_ocupar = ['tipo_documento ACEPTA', 'Nro. SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'RUT Emisor SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'razon_social_emisor ACEPTA', 'folio_oc ACEPTA', 'Folio SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'Fecha Docto. SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'Monto Neto SII FACTURAS ELECTRONICAS/EXENTAS/NC', 
                     'Monto Exento SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'Monto IVA SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'Monto Total SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'Fecha Recep. SII FACTURAS ELECTRONICAS/EXENTAS/NC', 'Ubic. PRESUPUESTO',
                     'tarea_actual ACEPTA', 'estado_devengo ACEPTA', 'fecha_ingreso_rc ACEPTA', 'estado_nar ACEPTA', 'Motivo SCI', 'tiempo_diferencia', 'esta_al_dia', 'Evento Receptor SII FACTURAS ELECTRONICAS/EXENTAS/NC']

        df_util = df_izquierda[columnas_a_ocupar]

        return df_izquierda, df_util
    
    def guardar_dfs(self, df_completa, df_columnas_utiles):
        fecha_actual = str(pd.to_datetime('today')).split(' ')[0]
        nombre_archivo = f'PLANILLA DE CONTROL AL {fecha_actual}.xlsx'

        if nombre_archivo in os.listdir():
            with pd.ExcelWriter(nombre_archivo, engine = 'openpyxl', mode = 'a', if_sheet_exists = 'overlay') as writer:
                df_columnas_utiles.to_excel(writer)
        else:
            df_columnas_utiles.loc[:, 'Observaciones'] = None
            with pd.ExcelWriter(nombre_archivo, engine = 'openpyxl', mode = 'w') as writer:
                df_columnas_utiles.to_excel(writer)
        
        df_completa.to_excel('COMPLETA ' + nombre_archivo)

# %%
programa = GeneradorPlanillaFinanzas()
programa.correr_programa()
# Out:
# Leyendo input\Documentos recepcion SCI 12-09-2022.xlsx, es del tipo: SCI
# Leyendo input\DTE_RECIBIDOS_61608402_202209_33.csv, es del tipo: SII FACTURAS ELECTRONICAS/EXENTAS/NC
# Leyendo input\DTE_RECIBIDOS_61608402_202209_34.csv, es del tipo: SII FACTURAS ELECTRONICAS/EXENTAS/NC
# Leyendo input\DTE_RECIBIDOS_61608402_202209_61.csv, es del tipo: SII FACTURAS ELECTRONICAS/EXENTAS/NC
# Leyendo input\presupuesto_12-09-2022.xlsx, es del tipo: PRESUPUESTO
# Leyendo input\reporte_ACEPTA 12-09-2022.xls, es del tipo: ACEPTA
# Leyendo input\SA_CarteraFinancieraContable (25).xls, es del tipo: SIGFE
# Index(['Nro.', 'RUT Emisor', 'Folio', 'Fecha Docto.', 'Monto Neto',
#        'Monto Exento', 'Monto IVA', 'Monto Total', 'Fecha Recep.',
#        'Evento Receptor', 'Codigo Otro Impto', 'Valor Otro Impto',
#        'Tasa Otro Impto'],
#       dtype='object')
# Index(['Unnamed: 0', 'tipo', 'tipo_documento', 'Folio', 'RUT Emisor',
#        'razon_social_emisor', 'receptor', 'publicacion', 'emision',
#        'monto_neto', 'monto_exento', 'monto_iva', 'monto_total', 'impuestos',
#        'estado_acepta', 'estado_sii', 'estado_intercambio',
#        'informacion_intercambio', 'uri', 'referencias', 'fecha_nar',
#        'estado_nar', 'uri_nar', 'mensaje_nar', 'uri_arm', 'fecha_arm',
#        'fmapago', 'controller', 'fecha_vencimiento', 'estado_cesion',
#        'url_correo_cesion', 'fecha_recepcion_sii', 'estado_reclamo',
#        'fecha_reclamo', 'mensaje_reclamo', 'estado_devengo', 'codigo_devengo',
#        'folio_oc', 'fecha_ingreso_oc', 'folio_rc', 'fecha_ingreso_rc',
#        'ticket_devengo', 'folio_sigfe', 'tarea_actual', 'area_transaccional',
#        'fecha_ingreso', 'fecha_aceptacion', 'fecha'],
#       dtype='object')
# Index(['Unnamed: 0', 'N', 'RUT Emisor', 'Empresa', 'Tipo Doc.', 'Folio',
#        'NºC/D', 'Monto', 'Fecha E.', 'Fecha R.', 'Nº O/C', 'Ubic.', 'NºPresu',
#        'Folio_abreviado', 'NºPago', 'Fecha P.', 'NºEgreso', 'Id.Adqui.',
#        'NºOper.Pago'],
#       dtype='object')
# Index(['Unnamed: 0', 'N° Resolucion', 'RUT Emisor', 'Proveedor',
#        'Fecha Recepción', 'Registrador', 'Tipo Documento', 'Folio',
#        'Codigo Articulo', 'Articulo', 'N° Acta', 'Motivo', 'Accion'],
#       dtype='object')
# Index(['Cuenta Contable', 'Principal', 'Saldo', 'Tipo Movimiento', 'Fecha',
#        'Folio_abreviado', 'Título', 'Debe', 'Haber', 'Saldo Acumulado',
#        'Tipo Documento', 'Número ', 'Origen Transacción', 'RUT Emisor'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gmolina\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\gmolina\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\gmolina\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Folio SIGFE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\gmolina\Desktop\INT\Finanzas\proceso_facturas\gloria\12-09-2022\programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb Celda 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> programa = GeneradorPlanillaFinanzas()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> programa.correr_programa()
#
# c:\Users\gmolina\Desktop\INT\Finanzas\proceso_facturas\gloria\12-09-2022\programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb Celda 3 in GeneradorPlanillaFinanzas.correr_programa(self)
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> def correr_programa(self):
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     diccionario_dfs = self.identificar_tipo_de_archivo_y_cargar_dfs()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     dfs_limpias = self.limpiar_dfs(diccionario_dfs)
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a>     df_completa, df_columnas_utiles = self.unir_dfs(dfs_limpias)
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     self.guardar_dfs(df_completa, df_columnas_utiles)
#
# c:\Users\gmolina\Desktop\INT\Finanzas\proceso_facturas\gloria\12-09-2022\programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb Celda 3 in GeneradorPlanillaFinanzas.limpiar_dfs(self, diccionario_dfs)
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=74'>75</a>     df.columns = df.columns + f' {nombre_tabla}'
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=76'>77</a>     df[f'RUT Emisor {nombre_tabla}'] = df[f'RUT Emisor {nombre_tabla}'].apply(lambda rut: rut.replace('.', '').upper().strip())
# ---> <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=78'>79</a>     df['llave_id'] = df[f'RUT Emisor {nombre_tabla}'] + df[f'Folio {nombre_tabla}'].astype(str)
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=79'>80</a>     df.set_index('llave_id', drop = True, inplace = True)
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/INT/Finanzas/proceso_facturas/gloria/12-09-2022/programa_hacer_matriz_sii_exentas_presupuesto_sci.ipynb#W2sZmlsZQ%3D%3D?line=81'>82</a> return diccionario_dfs
#
# File c:\Users\gmolina\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\gmolina\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Folio SIGFE'
