# %%
import pandas as pd
import numpy as np
import random
from constantes import TRADUCTOR_DESTINO_INT_CC_SIGCOM_JSON, TRADUCTOR_ITEM_SIGFE_ITEM_SIGCOM_JSON

# %%
df = pd.read_excel('item_cc_rellenados_completos.xlsx')
tabla_din = pd.pivot_table(df, values = 'Neto Total', index = 'CC SIGCOM', columns = 'Item SIGCOM', aggfunc=np.sum)
tabla_din.to_excel('output.xlsx')

# %%
formato = pd.read_excel('input\\Formato 4_Distribución Suministro 2022-10.xlsx')
formato = formato.set_index('Centro de Costo')

# %%
formato
# Out:
#                                             3-COMBUSTIBLES Y LUBRICANTES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                  NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                        NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                   NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                        NaN
# 484-QUIRÓFANOS TORACICA                                              NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                    NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                           NaN
# 15105-CONSULTA CARDIOLOGÍA                                           NaN
# 15107-CONSULTA ONCOLOGÍA                                             NaN
# 15111-CONSULTA NEUMOLOGÍA                                            NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                      NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                       NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                      NaN
# 15008-CONSULTA NUTRICIÓN                                             NaN
# 15010-CONSULTA OTROS PROFESIONALES                                   NaN
# 631-CENTRO DE COSTOS EXTERNO                                         NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                    NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                            NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                  NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                    NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                        NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                  NaN
# 264-PROCEDIMIENTOS EBUS                                              NaN
# 265-PROCEDIMIENTOS ECMO                                              NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                      NaN
# 270-PROCEDIMIENTOS TAVI                                              NaN
# 518-LABORATORIO CLÍNICO                                              NaN
# 537-ECOCARDIOGRAFÍA                                                  NaN
# 41107-TOMOGRAFÍA                                                     NaN
# 41108-IMAGENOLOGÍA                                                   NaN
# 544-ANATOMÍA PATOLÓGICA                                              NaN
# 51001-BANCO DE SANGRE                                                NaN
# 55101-SERVICIO FARMACEUTICO                                          NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                      NaN
# 652-SERVICIO DE ALIMENTACIÓN                                         NaN
# 95501-MANTENIMIENTO                                                  NaN
# 670-ADMINISTRACIÓN                                                   NaN
#
#                                             8-EQUIPOS MENORES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                             NaN
# 484-QUIRÓFANOS TORACICA                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                NaN
# 15105-CONSULTA CARDIOLOGÍA                                NaN
# 15107-CONSULTA ONCOLOGÍA                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                           NaN
# 15008-CONSULTA NUTRICIÓN                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                        NaN
# 631-CENTRO DE COSTOS EXTERNO                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                       NaN
# 264-PROCEDIMIENTOS EBUS                                   NaN
# 265-PROCEDIMIENTOS ECMO                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                           NaN
# 270-PROCEDIMIENTOS TAVI                                   NaN
# 518-LABORATORIO CLÍNICO                                   NaN
# 537-ECOCARDIOGRAFÍA                                       NaN
# 41107-TOMOGRAFÍA                                          NaN
# 41108-IMAGENOLOGÍA                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                   NaN
# 51001-BANCO DE SANGRE                                     NaN
# 55101-SERVICIO FARMACEUTICO                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                              NaN
# 95501-MANTENIMIENTO                                       NaN
# 670-ADMINISTRACIÓN                                        NaN
#
#                                             9-GASES MEDICINALES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                         NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                               NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                          NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                               NaN
# 484-QUIRÓFANOS TORACICA                                     NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                           NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                  NaN
# 15105-CONSULTA CARDIOLOGÍA                                  NaN
# 15107-CONSULTA ONCOLOGÍA                                    NaN
# 15111-CONSULTA NEUMOLOGÍA                                   NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                             NaN
# 15201-CONSULTA CIRUGÍA GENERAL                              NaN
# 15220-CONSULTA CIRUGIA CARDIACA                             NaN
# 15008-CONSULTA NUTRICIÓN                                    NaN
# 15010-CONSULTA OTROS PROFESIONALES                          NaN
# 631-CENTRO DE COSTOS EXTERNO                                NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                           NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                   NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                         NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                           NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                               NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                         NaN
# 264-PROCEDIMIENTOS EBUS                                     NaN
# 265-PROCEDIMIENTOS ECMO                                     NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                             NaN
# 270-PROCEDIMIENTOS TAVI                                     NaN
# 518-LABORATORIO CLÍNICO                                     NaN
# 537-ECOCARDIOGRAFÍA                                         NaN
# 41107-TOMOGRAFÍA                                            NaN
# 41108-IMAGENOLOGÍA                                          NaN
# 544-ANATOMÍA PATOLÓGICA                                     NaN
# 51001-BANCO DE SANGRE                                       NaN
# 55101-SERVICIO FARMACEUTICO                                 NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                             NaN
# 652-SERVICIO DE ALIMENTACIÓN                                NaN
# 95501-MANTENIMIENTO                                         NaN
# 670-ADMINISTRACIÓN                                          NaN
#
#                                             11-LIBROS, TEXTOS, UTILES DE ENSEÑANZA Y PUBLICACIONES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                        NaN
#
#                                             15-MATERIAL DE ODONTOLOGÍA  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                      NaN
# 484-QUIRÓFANOS TORACICA                                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                  NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                         NaN
# 15105-CONSULTA CARDIOLOGÍA                                         NaN
# 15107-CONSULTA ONCOLOGÍA                                           NaN
# 15111-CONSULTA NEUMOLOGÍA                                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                    NaN
# 15008-CONSULTA NUTRICIÓN                                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                                 NaN
# 631-CENTRO DE COSTOS EXTERNO                                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                  NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                NaN
# 264-PROCEDIMIENTOS EBUS                                            NaN
# 265-PROCEDIMIENTOS ECMO                                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                    NaN
# 270-PROCEDIMIENTOS TAVI                                            NaN
# 518-LABORATORIO CLÍNICO                                            NaN
# 537-ECOCARDIOGRAFÍA                                                NaN
# 41107-TOMOGRAFÍA                                                   NaN
# 41108-IMAGENOLOGÍA                                                 NaN
# 544-ANATOMÍA PATOLÓGICA                                            NaN
# 51001-BANCO DE SANGRE                                              NaN
# 55101-SERVICIO FARMACEUTICO                                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                                       NaN
# 95501-MANTENIMIENTO                                                NaN
# 670-ADMINISTRACIÓN                                                 NaN
#
#                                             16-MATERIAL DE OSTEOSÍNTESIS Y PRÓTESIS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                             NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                   NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                              NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                   NaN
# 484-QUIRÓFANOS TORACICA                                                         NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                               NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                      NaN
# 15105-CONSULTA CARDIOLOGÍA                                                      NaN
# 15107-CONSULTA ONCOLOGÍA                                                        NaN
# 15111-CONSULTA NEUMOLOGÍA                                                       NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                 NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                  NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                 NaN
# 15008-CONSULTA NUTRICIÓN                                                        NaN
# 15010-CONSULTA OTROS PROFESIONALES                                              NaN
# 631-CENTRO DE COSTOS EXTERNO                                                    NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                               NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                       NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                             NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                               NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                   NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                             NaN
# 264-PROCEDIMIENTOS EBUS                                                         NaN
# 265-PROCEDIMIENTOS ECMO                                                         NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                 NaN
# 270-PROCEDIMIENTOS TAVI                                                         NaN
# 518-LABORATORIO CLÍNICO                                                         NaN
# 537-ECOCARDIOGRAFÍA                                                             NaN
# 41107-TOMOGRAFÍA                                                                NaN
# 41108-IMAGENOLOGÍA                                                              NaN
# 544-ANATOMÍA PATOLÓGICA                                                         NaN
# 51001-BANCO DE SANGRE                                                           NaN
# 55101-SERVICIO FARMACEUTICO                                                     NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                 NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                    NaN
# 95501-MANTENIMIENTO                                                             NaN
# 670-ADMINISTRACIÓN                                                              NaN
#
#                                             18-MATERIAL MEDICO QUIRURGICO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                   NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                         NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                    NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                         NaN
# 484-QUIRÓFANOS TORACICA                                               NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                     NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                            NaN
# 15105-CONSULTA CARDIOLOGÍA                                            NaN
# 15107-CONSULTA ONCOLOGÍA                                              NaN
# 15111-CONSULTA NEUMOLOGÍA                                             NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                       NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                        NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                       NaN
# 15008-CONSULTA NUTRICIÓN                                              NaN
# 15010-CONSULTA OTROS PROFESIONALES                                    NaN
# 631-CENTRO DE COSTOS EXTERNO                                          NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                     NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                             NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                   NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                     NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                         NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                   NaN
# 264-PROCEDIMIENTOS EBUS                                               NaN
# 265-PROCEDIMIENTOS ECMO                                               NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                       NaN
# 270-PROCEDIMIENTOS TAVI                                               NaN
# 518-LABORATORIO CLÍNICO                                               NaN
# 537-ECOCARDIOGRAFÍA                                                   NaN
# 41107-TOMOGRAFÍA                                                      NaN
# 41108-IMAGENOLOGÍA                                                    NaN
# 544-ANATOMÍA PATOLÓGICA                                               NaN
# 51001-BANCO DE SANGRE                                                 NaN
# 55101-SERVICIO FARMACEUTICO                                           NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                       NaN
# 652-SERVICIO DE ALIMENTACIÓN                                          NaN
# 95501-MANTENIMIENTO                                                   NaN
# 670-ADMINISTRACIÓN                                                    NaN
#
#                                             21-MATERIALES DE CURACIÓN  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                               NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                     NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                     NaN
# 484-QUIRÓFANOS TORACICA                                           NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                 NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                        NaN
# 15105-CONSULTA CARDIOLOGÍA                                        NaN
# 15107-CONSULTA ONCOLOGÍA                                          NaN
# 15111-CONSULTA NEUMOLOGÍA                                         NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                   NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                    NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                   NaN
# 15008-CONSULTA NUTRICIÓN                                          NaN
# 15010-CONSULTA OTROS PROFESIONALES                                NaN
# 631-CENTRO DE COSTOS EXTERNO                                      NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                 NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                         NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                               NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                 NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                     NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                               NaN
# 264-PROCEDIMIENTOS EBUS                                           NaN
# 265-PROCEDIMIENTOS ECMO                                           NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                   NaN
# 270-PROCEDIMIENTOS TAVI                                           NaN
# 518-LABORATORIO CLÍNICO                                           NaN
# 537-ECOCARDIOGRAFÍA                                               NaN
# 41107-TOMOGRAFÍA                                                  NaN
# 41108-IMAGENOLOGÍA                                                NaN
# 544-ANATOMÍA PATOLÓGICA                                           NaN
# 51001-BANCO DE SANGRE                                             NaN
# 55101-SERVICIO FARMACEUTICO                                       NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                   NaN
# 652-SERVICIO DE ALIMENTACIÓN                                      NaN
# 95501-MANTENIMIENTO                                               NaN
# 670-ADMINISTRACIÓN                                                NaN
#
#                                             24-MATERIALES DE OFICINA, PRODUCTOS DE PAPEL E IMPRESOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                        NaN
#
#                                             25-MATERIALES DE USO O CONSUMO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                    NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                          NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                     NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                          NaN
# 484-QUIRÓFANOS TORACICA                                                NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                      NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                             NaN
# 15105-CONSULTA CARDIOLOGÍA                                             NaN
# 15107-CONSULTA ONCOLOGÍA                                               NaN
# 15111-CONSULTA NEUMOLOGÍA                                              NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                        NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                         NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                        NaN
# 15008-CONSULTA NUTRICIÓN                                               NaN
# 15010-CONSULTA OTROS PROFESIONALES                                     NaN
# 631-CENTRO DE COSTOS EXTERNO                                           NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                      NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                              NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                    NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                      NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                          NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                    NaN
# 264-PROCEDIMIENTOS EBUS                                                NaN
# 265-PROCEDIMIENTOS ECMO                                                NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                        NaN
# 270-PROCEDIMIENTOS TAVI                                                NaN
# 518-LABORATORIO CLÍNICO                                                NaN
# 537-ECOCARDIOGRAFÍA                                                    NaN
# 41107-TOMOGRAFÍA                                                       NaN
# 41108-IMAGENOLOGÍA                                                     NaN
# 544-ANATOMÍA PATOLÓGICA                                                NaN
# 51001-BANCO DE SANGRE                                                  NaN
# 55101-SERVICIO FARMACEUTICO                                            NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                        NaN
# 652-SERVICIO DE ALIMENTACIÓN                                           NaN
# 95501-MANTENIMIENTO                                                    NaN
# 670-ADMINISTRACIÓN                                                     NaN
#
#                                             27-MATERIALES INFORMATICOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                      NaN
# 484-QUIRÓFANOS TORACICA                                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                  NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                         NaN
# 15105-CONSULTA CARDIOLOGÍA                                         NaN
# 15107-CONSULTA ONCOLOGÍA                                           NaN
# 15111-CONSULTA NEUMOLOGÍA                                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                    NaN
# 15008-CONSULTA NUTRICIÓN                                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                                 NaN
# 631-CENTRO DE COSTOS EXTERNO                                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                  NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                NaN
# 264-PROCEDIMIENTOS EBUS                                            NaN
# 265-PROCEDIMIENTOS ECMO                                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                    NaN
# 270-PROCEDIMIENTOS TAVI                                            NaN
# 518-LABORATORIO CLÍNICO                                            NaN
# 537-ECOCARDIOGRAFÍA                                                NaN
# 41107-TOMOGRAFÍA                                                   NaN
# 41108-IMAGENOLOGÍA                                                 NaN
# 544-ANATOMÍA PATOLÓGICA                                            NaN
# 51001-BANCO DE SANGRE                                              NaN
# 55101-SERVICIO FARMACEUTICO                                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                                       NaN
# 95501-MANTENIMIENTO                                                NaN
# 670-ADMINISTRACIÓN                                                 NaN
#
#                                             28-MATERIALES PARA MANTENIMIENTO Y REPARACIONES DE INMUEBLES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                        NaN
#
#                                             29-MATERIALES Y ELEMENTOS DE ASEO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                             NaN
# 484-QUIRÓFANOS TORACICA                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                   NaN
# 518-LABORATORIO CLÍNICO                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                       NaN
# 41107-TOMOGRAFÍA                                                          NaN
# 41108-IMAGENOLOGÍA                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                   NaN
# 51001-BANCO DE SANGRE                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                              NaN
# 95501-MANTENIMIENTO                                                       NaN
# 670-ADMINISTRACIÓN                                                        NaN
#
#                                             30-MEDICAMENTOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                     NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                           NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                      NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                           NaN
# 484-QUIRÓFANOS TORACICA                                 NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                       NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO              NaN
# 15105-CONSULTA CARDIOLOGÍA                              NaN
# 15107-CONSULTA ONCOLOGÍA                                NaN
# 15111-CONSULTA NEUMOLOGÍA                               NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                         NaN
# 15201-CONSULTA CIRUGÍA GENERAL                          NaN
# 15220-CONSULTA CIRUGIA CARDIACA                         NaN
# 15008-CONSULTA NUTRICIÓN                                NaN
# 15010-CONSULTA OTROS PROFESIONALES                      NaN
# 631-CENTRO DE COSTOS EXTERNO                            NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                       NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR               NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                     NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                       NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                           NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                     NaN
# 264-PROCEDIMIENTOS EBUS                                 NaN
# 265-PROCEDIMIENTOS ECMO                                 NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                         NaN
# 270-PROCEDIMIENTOS TAVI                                 NaN
# 518-LABORATORIO CLÍNICO                                 NaN
# 537-ECOCARDIOGRAFÍA                                     NaN
# 41107-TOMOGRAFÍA                                        NaN
# 41108-IMAGENOLOGÍA                                      NaN
# 544-ANATOMÍA PATOLÓGICA                                 NaN
# 51001-BANCO DE SANGRE                                   NaN
# 55101-SERVICIO FARMACEUTICO                             NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                         NaN
# 652-SERVICIO DE ALIMENTACIÓN                            NaN
# 95501-MANTENIMIENTO                                     NaN
# 670-ADMINISTRACIÓN                                      NaN
#
#                                             31-MENAJE PARA OFICINA, CASINO Y OTROS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                            NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                  NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                             NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                  NaN
# 484-QUIRÓFANOS TORACICA                                                        NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                              NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                     NaN
# 15105-CONSULTA CARDIOLOGÍA                                                     NaN
# 15107-CONSULTA ONCOLOGÍA                                                       NaN
# 15111-CONSULTA NEUMOLOGÍA                                                      NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                 NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                NaN
# 15008-CONSULTA NUTRICIÓN                                                       NaN
# 15010-CONSULTA OTROS PROFESIONALES                                             NaN
# 631-CENTRO DE COSTOS EXTERNO                                                   NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                              NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                      NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                            NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                              NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                  NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                            NaN
# 264-PROCEDIMIENTOS EBUS                                                        NaN
# 265-PROCEDIMIENTOS ECMO                                                        NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                NaN
# 270-PROCEDIMIENTOS TAVI                                                        NaN
# 518-LABORATORIO CLÍNICO                                                        NaN
# 537-ECOCARDIOGRAFÍA                                                            NaN
# 41107-TOMOGRAFÍA                                                               NaN
# 41108-IMAGENOLOGÍA                                                             NaN
# 544-ANATOMÍA PATOLÓGICA                                                        NaN
# 51001-BANCO DE SANGRE                                                          NaN
# 55101-SERVICIO FARMACEUTICO                                                    NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                   NaN
# 95501-MANTENIMIENTO                                                            NaN
# 670-ADMINISTRACIÓN                                                             NaN
#
#                                             35-OTROS INSUMOS Y MATERIALES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                   NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                         NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                    NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                         NaN
# 484-QUIRÓFANOS TORACICA                                               NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                     NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                            NaN
# 15105-CONSULTA CARDIOLOGÍA                                            NaN
# 15107-CONSULTA ONCOLOGÍA                                              NaN
# 15111-CONSULTA NEUMOLOGÍA                                             NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                       NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                        NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                       NaN
# 15008-CONSULTA NUTRICIÓN                                              NaN
# 15010-CONSULTA OTROS PROFESIONALES                                    NaN
# 631-CENTRO DE COSTOS EXTERNO                                          NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                     NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                             NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                   NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                     NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                         NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                   NaN
# 264-PROCEDIMIENTOS EBUS                                               NaN
# 265-PROCEDIMIENTOS ECMO                                               NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                       NaN
# 270-PROCEDIMIENTOS TAVI                                               NaN
# 518-LABORATORIO CLÍNICO                                               NaN
# 537-ECOCARDIOGRAFÍA                                                   NaN
# 41107-TOMOGRAFÍA                                                      NaN
# 41108-IMAGENOLOGÍA                                                    NaN
# 544-ANATOMÍA PATOLÓGICA                                               NaN
# 51001-BANCO DE SANGRE                                                 NaN
# 55101-SERVICIO FARMACEUTICO                                           NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                       NaN
# 652-SERVICIO DE ALIMENTACIÓN                                          NaN
# 95501-MANTENIMIENTO                                                   NaN
# 670-ADMINISTRACIÓN                                                    NaN
#
#                                             41-PRODUCTOS QUÍMICOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                           NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                 NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                            NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                 NaN
# 484-QUIRÓFANOS TORACICA                                       NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                             NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                    NaN
# 15105-CONSULTA CARDIOLOGÍA                                    NaN
# 15107-CONSULTA ONCOLOGÍA                                      NaN
# 15111-CONSULTA NEUMOLOGÍA                                     NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                               NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                NaN
# 15220-CONSULTA CIRUGIA CARDIACA                               NaN
# 15008-CONSULTA NUTRICIÓN                                      NaN
# 15010-CONSULTA OTROS PROFESIONALES                            NaN
# 631-CENTRO DE COSTOS EXTERNO                                  NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                             NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                     NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                           NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                             NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                 NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                           NaN
# 264-PROCEDIMIENTOS EBUS                                       NaN
# 265-PROCEDIMIENTOS ECMO                                       NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                               NaN
# 270-PROCEDIMIENTOS TAVI                                       NaN
# 518-LABORATORIO CLÍNICO                                       NaN
# 537-ECOCARDIOGRAFÍA                                           NaN
# 41107-TOMOGRAFÍA                                              NaN
# 41108-IMAGENOLOGÍA                                            NaN
# 544-ANATOMÍA PATOLÓGICA                                       NaN
# 51001-BANCO DE SANGRE                                         NaN
# 55101-SERVICIO FARMACEUTICO                                   NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                               NaN
# 652-SERVICIO DE ALIMENTACIÓN                                  NaN
# 95501-MANTENIMIENTO                                           NaN
# 670-ADMINISTRACIÓN                                            NaN
#
#                                             43-PRODUCTOS TEXTILES, VESTUARIO Y CALZADO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                      NaN
# 484-QUIRÓFANOS TORACICA                                                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                  NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                         NaN
# 15105-CONSULTA CARDIOLOGÍA                                                         NaN
# 15107-CONSULTA ONCOLOGÍA                                                           NaN
# 15111-CONSULTA NEUMOLOGÍA                                                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                    NaN
# 15008-CONSULTA NUTRICIÓN                                                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                 NaN
# 631-CENTRO DE COSTOS EXTERNO                                                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                  NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                NaN
# 264-PROCEDIMIENTOS EBUS                                                            NaN
# 265-PROCEDIMIENTOS ECMO                                                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                    NaN
# 270-PROCEDIMIENTOS TAVI                                                            NaN
# 518-LABORATORIO CLÍNICO                                                            NaN
# 537-ECOCARDIOGRAFÍA                                                                NaN
# 41107-TOMOGRAFÍA                                                                   NaN
# 41108-IMAGENOLOGÍA                                                                 NaN
# 544-ANATOMÍA PATOLÓGICA                                                            NaN
# 51001-BANCO DE SANGRE                                                              NaN
# 55101-SERVICIO FARMACEUTICO                                                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                       NaN
# 95501-MANTENIMIENTO                                                                NaN
# 670-ADMINISTRACIÓN                                                                 NaN
#
#                                             44-REPUESTOS Y ACCESORIOS PARA MANTENIMIENTO Y REPARACIONES DE VEHICULOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                        NaN
#
#                                             46-VÍVERES
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                      NaN
# 484-QUIRÓFANOS TORACICA                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                  NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO         NaN
# 15105-CONSULTA CARDIOLOGÍA                         NaN
# 15107-CONSULTA ONCOLOGÍA                           NaN
# 15111-CONSULTA NEUMOLOGÍA                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                    NaN
# 15008-CONSULTA NUTRICIÓN                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                 NaN
# 631-CENTRO DE COSTOS EXTERNO                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                  NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                NaN
# 264-PROCEDIMIENTOS EBUS                            NaN
# 265-PROCEDIMIENTOS ECMO                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                    NaN
# 270-PROCEDIMIENTOS TAVI                            NaN
# 518-LABORATORIO CLÍNICO                            NaN
# 537-ECOCARDIOGRAFÍA                                NaN
# 41107-TOMOGRAFÍA                                   NaN
# 41108-IMAGENOLOGÍA                                 NaN
# 544-ANATOMÍA PATOLÓGICA                            NaN
# 51001-BANCO DE SANGRE                              NaN
# 55101-SERVICIO FARMACEUTICO                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                       NaN
# 95501-MANTENIMIENTO                                NaN
# 670-ADMINISTRACIÓN                                 NaN

# %%
for cc in tabla_din.index:
    for item_sigcom in tabla_din.columns:
        formato.loc[cc, item_sigcom] = tabla_din.loc[cc, item_sigcom]

# %%
formato.to_excel('formato_rellenandose.xlsx')
# Out:
#                                             3-COMBUSTIBLES Y LUBRICANTES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                  NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                        NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                   NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                        NaN
# 484-QUIRÓFANOS TORACICA                                              NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                    NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                           NaN
# 15105-CONSULTA CARDIOLOGÍA                                           NaN
# 15107-CONSULTA ONCOLOGÍA                                             NaN
# 15111-CONSULTA NEUMOLOGÍA                                            NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                      NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                       NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                      NaN
# 15008-CONSULTA NUTRICIÓN                                             NaN
# 15010-CONSULTA OTROS PROFESIONALES                                   NaN
# 631-CENTRO DE COSTOS EXTERNO                                         NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                    NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                            NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                  NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                    NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                        NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                  NaN
# 264-PROCEDIMIENTOS EBUS                                              NaN
# 265-PROCEDIMIENTOS ECMO                                              NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                      NaN
# 270-PROCEDIMIENTOS TAVI                                              NaN
# 518-LABORATORIO CLÍNICO                                              NaN
# 537-ECOCARDIOGRAFÍA                                                  NaN
# 41107-TOMOGRAFÍA                                                     NaN
# 41108-IMAGENOLOGÍA                                                   NaN
# 544-ANATOMÍA PATOLÓGICA                                              NaN
# 51001-BANCO DE SANGRE                                                NaN
# 55101-SERVICIO FARMACEUTICO                                          NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                      NaN
# 652-SERVICIO DE ALIMENTACIÓN                                         NaN
# 95501-MANTENIMIENTO                                                  NaN
# 670-ADMINISTRACIÓN                                                   NaN
# PABELLÓN                                                             NaN
#
#                                             8-EQUIPOS MENORES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                             NaN
# 484-QUIRÓFANOS TORACICA                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                NaN
# 15105-CONSULTA CARDIOLOGÍA                                NaN
# 15107-CONSULTA ONCOLOGÍA                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                           NaN
# 15008-CONSULTA NUTRICIÓN                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                        NaN
# 631-CENTRO DE COSTOS EXTERNO                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                       NaN
# 264-PROCEDIMIENTOS EBUS                                   NaN
# 265-PROCEDIMIENTOS ECMO                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                           NaN
# 270-PROCEDIMIENTOS TAVI                                   NaN
# 518-LABORATORIO CLÍNICO                                   NaN
# 537-ECOCARDIOGRAFÍA                                       NaN
# 41107-TOMOGRAFÍA                                          NaN
# 41108-IMAGENOLOGÍA                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                   NaN
# 51001-BANCO DE SANGRE                                     NaN
# 55101-SERVICIO FARMACEUTICO                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                              NaN
# 95501-MANTENIMIENTO                                       NaN
# 670-ADMINISTRACIÓN                                  116380.11
# PABELLÓN                                                  NaN
#
#                                             9-GASES MEDICINALES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                         NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                               NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                          NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                               NaN
# 484-QUIRÓFANOS TORACICA                                     NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                           NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                  NaN
# 15105-CONSULTA CARDIOLOGÍA                                  NaN
# 15107-CONSULTA ONCOLOGÍA                                    NaN
# 15111-CONSULTA NEUMOLOGÍA                                   NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                             NaN
# 15201-CONSULTA CIRUGÍA GENERAL                              NaN
# 15220-CONSULTA CIRUGIA CARDIACA                             NaN
# 15008-CONSULTA NUTRICIÓN                                    NaN
# 15010-CONSULTA OTROS PROFESIONALES                          NaN
# 631-CENTRO DE COSTOS EXTERNO                                NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                           NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                   NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                         NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                           NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                               NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                         NaN
# 264-PROCEDIMIENTOS EBUS                                     NaN
# 265-PROCEDIMIENTOS ECMO                                     NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                             NaN
# 270-PROCEDIMIENTOS TAVI                                     NaN
# 518-LABORATORIO CLÍNICO                                     NaN
# 537-ECOCARDIOGRAFÍA                                         NaN
# 41107-TOMOGRAFÍA                                            NaN
# 41108-IMAGENOLOGÍA                                          NaN
# 544-ANATOMÍA PATOLÓGICA                                     NaN
# 51001-BANCO DE SANGRE                                       NaN
# 55101-SERVICIO FARMACEUTICO                                 NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                             NaN
# 652-SERVICIO DE ALIMENTACIÓN                                NaN
# 95501-MANTENIMIENTO                                         NaN
# 670-ADMINISTRACIÓN                                          NaN
# PABELLÓN                                                    NaN
#
#                                             11-LIBROS, TEXTOS, UTILES DE ENSEÑANZA Y PUBLICACIONES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                        NaN
# PABELLÓN                                                                                  NaN
#
#                                             15-MATERIAL DE ODONTOLOGÍA  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                      NaN
# 484-QUIRÓFANOS TORACICA                                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                  NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                         NaN
# 15105-CONSULTA CARDIOLOGÍA                                         NaN
# 15107-CONSULTA ONCOLOGÍA                                           NaN
# 15111-CONSULTA NEUMOLOGÍA                                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                    NaN
# 15008-CONSULTA NUTRICIÓN                                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                                 NaN
# 631-CENTRO DE COSTOS EXTERNO                                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                  NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                NaN
# 264-PROCEDIMIENTOS EBUS                                            NaN
# 265-PROCEDIMIENTOS ECMO                                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                    NaN
# 270-PROCEDIMIENTOS TAVI                                            NaN
# 518-LABORATORIO CLÍNICO                                            NaN
# 537-ECOCARDIOGRAFÍA                                                NaN
# 41107-TOMOGRAFÍA                                                   NaN
# 41108-IMAGENOLOGÍA                                                 NaN
# 544-ANATOMÍA PATOLÓGICA                                            NaN
# 51001-BANCO DE SANGRE                                              NaN
# 55101-SERVICIO FARMACEUTICO                                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                                       NaN
# 95501-MANTENIMIENTO                                                NaN
# 670-ADMINISTRACIÓN                                                 NaN
# PABELLÓN                                                           NaN
#
#                                             16-MATERIAL DE OSTEOSÍNTESIS Y PRÓTESIS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                             NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                   NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                              NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                   NaN
# 484-QUIRÓFANOS TORACICA                                                         NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                               NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                      NaN
# 15105-CONSULTA CARDIOLOGÍA                                                      NaN
# 15107-CONSULTA ONCOLOGÍA                                                        NaN
# 15111-CONSULTA NEUMOLOGÍA                                                       NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                 NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                  NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                 NaN
# 15008-CONSULTA NUTRICIÓN                                                        NaN
# 15010-CONSULTA OTROS PROFESIONALES                                              NaN
# 631-CENTRO DE COSTOS EXTERNO                                                    NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                               NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                       NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                       9680000.0
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                               NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                   NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                             NaN
# 264-PROCEDIMIENTOS EBUS                                                         NaN
# 265-PROCEDIMIENTOS ECMO                                                         NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                 NaN
# 270-PROCEDIMIENTOS TAVI                                                         NaN
# 518-LABORATORIO CLÍNICO                                                         NaN
# 537-ECOCARDIOGRAFÍA                                                             NaN
# 41107-TOMOGRAFÍA                                                                NaN
# 41108-IMAGENOLOGÍA                                                              NaN
# 544-ANATOMÍA PATOLÓGICA                                                         NaN
# 51001-BANCO DE SANGRE                                                           NaN
# 55101-SERVICIO FARMACEUTICO                                                     NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                 NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                    NaN
# 95501-MANTENIMIENTO                                                             NaN
# 670-ADMINISTRACIÓN                                                              NaN
# PABELLÓN                                                                 51782130.0
#
#                                             18-MATERIAL MEDICO QUIRURGICO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                          2.721668e+07
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                         NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                    NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                5.016889e+06
# 484-QUIRÓFANOS TORACICA                                      3.510800e+05
# 166-UNIDAD DE CUIDADOS INTENSIVOS                            2.905329e+07
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                            NaN
# 15105-CONSULTA CARDIOLOGÍA                                            NaN
# 15107-CONSULTA ONCOLOGÍA                                              NaN
# 15111-CONSULTA NEUMOLOGÍA                                             NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                       NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                        NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                       NaN
# 15008-CONSULTA NUTRICIÓN                                              NaN
# 15010-CONSULTA OTROS PROFESIONALES                           6.123235e+06
# 631-CENTRO DE COSTOS EXTERNO                                          NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                     NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                             NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                          2.479805e+07
# 253-PROCEDIMIENTOS DE HEMODINAMIA                            6.788560e+07
# 15038-PROCEDIMIENTO ONCOLOGÍA                                         NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                   NaN
# 264-PROCEDIMIENTOS EBUS                                               NaN
# 265-PROCEDIMIENTOS ECMO                                               NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                              2.114375e+07
# 270-PROCEDIMIENTOS TAVI                                               NaN
# 518-LABORATORIO CLÍNICO                                      2.414427e+07
# 537-ECOCARDIOGRAFÍA                                          9.913840e+05
# 41107-TOMOGRAFÍA                                                      NaN
# 41108-IMAGENOLOGÍA                                           1.365572e+07
# 544-ANATOMÍA PATOLÓGICA                                      1.851280e+06
# 51001-BANCO DE SANGRE                                                 NaN
# 55101-SERVICIO FARMACEUTICO                                           NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                              6.678745e+06
# 652-SERVICIO DE ALIMENTACIÓN                                 1.353596e+06
# 95501-MANTENIMIENTO                                                   NaN
# 670-ADMINISTRACIÓN                                           1.326936e+07
# PABELLÓN                                                     1.801373e+08
#
#                                             21-MATERIALES DE CURACIÓN  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                               NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                     NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                     NaN
# 484-QUIRÓFANOS TORACICA                                           NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                 NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                        NaN
# 15105-CONSULTA CARDIOLOGÍA                                        NaN
# 15107-CONSULTA ONCOLOGÍA                                          NaN
# 15111-CONSULTA NEUMOLOGÍA                                         NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                   NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                    NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                   NaN
# 15008-CONSULTA NUTRICIÓN                                          NaN
# 15010-CONSULTA OTROS PROFESIONALES                                NaN
# 631-CENTRO DE COSTOS EXTERNO                                      NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                 NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                         NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                               NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                 NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                     NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                               NaN
# 264-PROCEDIMIENTOS EBUS                                           NaN
# 265-PROCEDIMIENTOS ECMO                                           NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                   NaN
# 270-PROCEDIMIENTOS TAVI                                           NaN
# 518-LABORATORIO CLÍNICO                                           NaN
# 537-ECOCARDIOGRAFÍA                                               NaN
# 41107-TOMOGRAFÍA                                                  NaN
# 41108-IMAGENOLOGÍA                                                NaN
# 544-ANATOMÍA PATOLÓGICA                                           NaN
# 51001-BANCO DE SANGRE                                             NaN
# 55101-SERVICIO FARMACEUTICO                                       NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                   NaN
# 652-SERVICIO DE ALIMENTACIÓN                                      NaN
# 95501-MANTENIMIENTO                                               NaN
# 670-ADMINISTRACIÓN                                                NaN
# PABELLÓN                                                          NaN
#
#                                             24-MATERIALES DE OFICINA, PRODUCTOS DE PAPEL E IMPRESOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                7384059.00
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                      8955180.72
# 484-QUIRÓFANOS TORACICA                                                               7856.00
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                   601564.00
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                   80204.80
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                    78018.00
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                 223676.00
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                    17692.00
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                     906236.00
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                             327437.00
# 537-ECOCARDIOGRAFÍA                                                                  18102.00
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                   70889.44
# 544-ANATOMÍA PATOLÓGICA                                                               4000.00
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                      15377.80
# 652-SERVICIO DE ALIMENTACIÓN                                                        115083.20
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                10268228.36
# PABELLÓN                                                                            239274.00
#
#                                             25-MATERIALES DE USO O CONSUMO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                    NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                          NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                     NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                          NaN
# 484-QUIRÓFANOS TORACICA                                                NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                      NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                             NaN
# 15105-CONSULTA CARDIOLOGÍA                                             NaN
# 15107-CONSULTA ONCOLOGÍA                                               NaN
# 15111-CONSULTA NEUMOLOGÍA                                              NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                        NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                         NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                        NaN
# 15008-CONSULTA NUTRICIÓN                                               NaN
# 15010-CONSULTA OTROS PROFESIONALES                                     NaN
# 631-CENTRO DE COSTOS EXTERNO                                           NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                      NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                              NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                    NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                      NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                          NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                    NaN
# 264-PROCEDIMIENTOS EBUS                                                NaN
# 265-PROCEDIMIENTOS ECMO                                                NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                        NaN
# 270-PROCEDIMIENTOS TAVI                                                NaN
# 518-LABORATORIO CLÍNICO                                                NaN
# 537-ECOCARDIOGRAFÍA                                                    NaN
# 41107-TOMOGRAFÍA                                                       NaN
# 41108-IMAGENOLOGÍA                                                     NaN
# 544-ANATOMÍA PATOLÓGICA                                                NaN
# 51001-BANCO DE SANGRE                                                  NaN
# 55101-SERVICIO FARMACEUTICO                                            NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                        NaN
# 652-SERVICIO DE ALIMENTACIÓN                                           NaN
# 95501-MANTENIMIENTO                                                    NaN
# 670-ADMINISTRACIÓN                                                     NaN
# PABELLÓN                                                               NaN
#
#                                             27-MATERIALES INFORMATICOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                      NaN
# 484-QUIRÓFANOS TORACICA                                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                               3250.0
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                         NaN
# 15105-CONSULTA CARDIOLOGÍA                                         NaN
# 15107-CONSULTA ONCOLOGÍA                                           NaN
# 15111-CONSULTA NEUMOLOGÍA                                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                    NaN
# 15008-CONSULTA NUTRICIÓN                                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                                 NaN
# 631-CENTRO DE COSTOS EXTERNO                                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                             217500.0
# 15038-PROCEDIMIENTO ONCOLOGÍA                                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                NaN
# 264-PROCEDIMIENTOS EBUS                                            NaN
# 265-PROCEDIMIENTOS ECMO                                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                    NaN
# 270-PROCEDIMIENTOS TAVI                                            NaN
# 518-LABORATORIO CLÍNICO                                       157304.0
# 537-ECOCARDIOGRAFÍA                                                NaN
# 41107-TOMOGRAFÍA                                                   NaN
# 41108-IMAGENOLOGÍA                                                 NaN
# 544-ANATOMÍA PATOLÓGICA                                            NaN
# 51001-BANCO DE SANGRE                                              NaN
# 55101-SERVICIO FARMACEUTICO                                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                                    9750.0
# 95501-MANTENIMIENTO                                                NaN
# 670-ADMINISTRACIÓN                                           1037534.0
# PABELLÓN                                                           NaN
#
#                                             28-MATERIALES PARA MANTENIMIENTO Y REPARACIONES DE INMUEBLES  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                        NaN
# PABELLÓN                                                                                  NaN
#
#                                             29-MATERIALES Y ELEMENTOS DE ASEO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                2097053.06
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                       665758.92
# 484-QUIRÓFANOS TORACICA                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                  1132086.04
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                    3640.32
# 631-CENTRO DE COSTOS EXTERNO                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                        0.00
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                   711552.40
# 15038-PROCEDIMIENTO ONCOLOGÍA                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                     418882.68
# 270-PROCEDIMIENTOS TAVI                                                   NaN
# 518-LABORATORIO CLÍNICO                                             181746.60
# 537-ECOCARDIOGRAFÍA                                                 111029.00
# 41107-TOMOGRAFÍA                                                          NaN
# 41108-IMAGENOLOGÍA                                                  352625.32
# 544-ANATOMÍA PATOLÓGICA                                              89318.00
# 51001-BANCO DE SANGRE                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                      25592.08
# 652-SERVICIO DE ALIMENTACIÓN                                        409504.67
# 95501-MANTENIMIENTO                                                       NaN
# 670-ADMINISTRACIÓN                                                 1679400.84
# PABELLÓN                                                            250601.00
#
#                                             30-MEDICAMENTOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                     NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                           NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                      NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                           NaN
# 484-QUIRÓFANOS TORACICA                                 NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                       NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO              NaN
# 15105-CONSULTA CARDIOLOGÍA                              NaN
# 15107-CONSULTA ONCOLOGÍA                                NaN
# 15111-CONSULTA NEUMOLOGÍA                               NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                         NaN
# 15201-CONSULTA CIRUGÍA GENERAL                          NaN
# 15220-CONSULTA CIRUGIA CARDIACA                         NaN
# 15008-CONSULTA NUTRICIÓN                                NaN
# 15010-CONSULTA OTROS PROFESIONALES                      NaN
# 631-CENTRO DE COSTOS EXTERNO                            NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                       NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR               NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                     NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                       NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                           NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                     NaN
# 264-PROCEDIMIENTOS EBUS                                 NaN
# 265-PROCEDIMIENTOS ECMO                                 NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                         NaN
# 270-PROCEDIMIENTOS TAVI                                 NaN
# 518-LABORATORIO CLÍNICO                                 NaN
# 537-ECOCARDIOGRAFÍA                                     NaN
# 41107-TOMOGRAFÍA                                        NaN
# 41108-IMAGENOLOGÍA                                      NaN
# 544-ANATOMÍA PATOLÓGICA                                 NaN
# 51001-BANCO DE SANGRE                                   NaN
# 55101-SERVICIO FARMACEUTICO                             NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                         NaN
# 652-SERVICIO DE ALIMENTACIÓN                            NaN
# 95501-MANTENIMIENTO                                     NaN
# 670-ADMINISTRACIÓN                                      NaN
# PABELLÓN                                                NaN
#
#                                             31-MENAJE PARA OFICINA, CASINO Y OTROS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                       42250.00
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                  NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                             NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                             17400.00
# 484-QUIRÓFANOS TORACICA                                                        NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                        133300.00
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                     NaN
# 15105-CONSULTA CARDIOLOGÍA                                                     NaN
# 15107-CONSULTA ONCOLOGÍA                                                       NaN
# 15111-CONSULTA NEUMOLOGÍA                                                      NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                 NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                NaN
# 15008-CONSULTA NUTRICIÓN                                                       NaN
# 15010-CONSULTA OTROS PROFESIONALES                                             NaN
# 631-CENTRO DE COSTOS EXTERNO                                                   NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                              NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                      NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                       24300.00
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                         52500.00
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                  NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                            NaN
# 264-PROCEDIMIENTOS EBUS                                                        NaN
# 265-PROCEDIMIENTOS ECMO                                                        NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                           10600.00
# 270-PROCEDIMIENTOS TAVI                                                        NaN
# 518-LABORATORIO CLÍNICO                                                   29000.00
# 537-ECOCARDIOGRAFÍA                                                       13200.00
# 41107-TOMOGRAFÍA                                                               NaN
# 41108-IMAGENOLOGÍA                                                             NaN
# 544-ANATOMÍA PATOLÓGICA                                                        NaN
# ...
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                            NaN
# 15105-CONSULTA CARDIOLOGÍA                                            NaN
# 15107-CONSULTA ONCOLOGÍA                                              NaN
# 15111-CONSULTA NEUMOLOGÍA                                             NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                       NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                        NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                       NaN
# 15008-CONSULTA NUTRICIÓN                                              NaN
# 15010-CONSULTA OTROS PROFESIONALES                                    NaN
# 631-CENTRO DE COSTOS EXTERNO                                          NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                     NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                             NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                   NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                     NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                         NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                   NaN
# 264-PROCEDIMIENTOS EBUS                                               NaN
# 265-PROCEDIMIENTOS ECMO                                               NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                       NaN
# 270-PROCEDIMIENTOS TAVI                                               NaN
# 518-LABORATORIO CLÍNICO                                               NaN
# 537-ECOCARDIOGRAFÍA                                                   NaN
# 41107-TOMOGRAFÍA                                                      NaN
# 41108-IMAGENOLOGÍA                                                    NaN
# 544-ANATOMÍA PATOLÓGICA                                               NaN
# 51001-BANCO DE SANGRE                                                 NaN
# 55101-SERVICIO FARMACEUTICO                                           NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                       NaN
# 652-SERVICIO DE ALIMENTACIÓN                                          NaN
# 95501-MANTENIMIENTO                                                   NaN
# 670-ADMINISTRACIÓN                                                    NaN
# PABELLÓN                                                              NaN
#
#                                             41-PRODUCTOS QUÍMICOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                           NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                 NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                            NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                 NaN
# 484-QUIRÓFANOS TORACICA                                       NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                             NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                    NaN
# 15105-CONSULTA CARDIOLOGÍA                                    NaN
# 15107-CONSULTA ONCOLOGÍA                                      NaN
# 15111-CONSULTA NEUMOLOGÍA                                     NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                               NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                NaN
# 15220-CONSULTA CIRUGIA CARDIACA                               NaN
# 15008-CONSULTA NUTRICIÓN                                      NaN
# 15010-CONSULTA OTROS PROFESIONALES                            NaN
# 631-CENTRO DE COSTOS EXTERNO                                  NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                             NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                     NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                           NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                             NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                 NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                           NaN
# 264-PROCEDIMIENTOS EBUS                                       NaN
# 265-PROCEDIMIENTOS ECMO                                       NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                               NaN
# 270-PROCEDIMIENTOS TAVI                                       NaN
# 518-LABORATORIO CLÍNICO                                33584981.0
# 537-ECOCARDIOGRAFÍA                                           NaN
# 41107-TOMOGRAFÍA                                              NaN
# 41108-IMAGENOLOGÍA                                            NaN
# 544-ANATOMÍA PATOLÓGICA                                10390900.0
# 51001-BANCO DE SANGRE                                         NaN
# 55101-SERVICIO FARMACEUTICO                                   NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                               NaN
# 652-SERVICIO DE ALIMENTACIÓN                                  NaN
# 95501-MANTENIMIENTO                                           NaN
# 670-ADMINISTRACIÓN                                            NaN
# PABELLÓN                                                 339200.0
#
#                                             43-PRODUCTOS TEXTILES, VESTUARIO Y CALZADO  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                      NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                 NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                      NaN
# 484-QUIRÓFANOS TORACICA                                                            NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                  NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                         NaN
# 15105-CONSULTA CARDIOLOGÍA                                                         NaN
# 15107-CONSULTA ONCOLOGÍA                                                           NaN
# 15111-CONSULTA NEUMOLOGÍA                                                          NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                    NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                     NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                    NaN
# 15008-CONSULTA NUTRICIÓN                                                           NaN
# 15010-CONSULTA OTROS PROFESIONALES                                             19328.0
# 631-CENTRO DE COSTOS EXTERNO                                                       NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                  NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                          NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                            18334.0
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                              55002.0
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                      NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                NaN
# 264-PROCEDIMIENTOS EBUS                                                            NaN
# 265-PROCEDIMIENTOS ECMO                                                            NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                 9167.0
# 270-PROCEDIMIENTOS TAVI                                                            NaN
# 518-LABORATORIO CLÍNICO                                                      2383420.0
# 537-ECOCARDIOGRAFÍA                                                             9167.0
# 41107-TOMOGRAFÍA                                                                   NaN
# 41108-IMAGENOLOGÍA                                                             27501.0
# 544-ANATOMÍA PATOLÓGICA                                                            NaN
# 51001-BANCO DE SANGRE                                                              NaN
# 55101-SERVICIO FARMACEUTICO                                                        NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                    NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                       NaN
# 95501-MANTENIMIENTO                                                                NaN
# 670-ADMINISTRACIÓN                                                            229637.1
# PABELLÓN                                                                       27501.0
#
#                                             44-REPUESTOS Y ACCESORIOS PARA MANTENIMIENTO Y REPARACIONES DE VEHICULOS  \
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                                                       NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                                                             NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                                                        NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                                                             NaN
# 484-QUIRÓFANOS TORACICA                                                                   NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                                                         NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO                                                NaN
# 15105-CONSULTA CARDIOLOGÍA                                                                NaN
# 15107-CONSULTA ONCOLOGÍA                                                                  NaN
# 15111-CONSULTA NEUMOLOGÍA                                                                 NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                                                           NaN
# 15201-CONSULTA CIRUGÍA GENERAL                                                            NaN
# 15220-CONSULTA CIRUGIA CARDIACA                                                           NaN
# 15008-CONSULTA NUTRICIÓN                                                                  NaN
# 15010-CONSULTA OTROS PROFESIONALES                                                        NaN
# 631-CENTRO DE COSTOS EXTERNO                                                              NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                                                         NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR                                                 NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                                                       NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                                                         NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                                                             NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                                                       NaN
# 264-PROCEDIMIENTOS EBUS                                                                   NaN
# 265-PROCEDIMIENTOS ECMO                                                                   NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                                                           NaN
# 270-PROCEDIMIENTOS TAVI                                                                   NaN
# 518-LABORATORIO CLÍNICO                                                                   NaN
# 537-ECOCARDIOGRAFÍA                                                                       NaN
# 41107-TOMOGRAFÍA                                                                          NaN
# 41108-IMAGENOLOGÍA                                                                        NaN
# 544-ANATOMÍA PATOLÓGICA                                                                   NaN
# 51001-BANCO DE SANGRE                                                                     NaN
# 55101-SERVICIO FARMACEUTICO                                                               NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                                                           NaN
# 652-SERVICIO DE ALIMENTACIÓN                                                              NaN
# 95501-MANTENIMIENTO                                                                       NaN
# 670-ADMINISTRACIÓN                                                                  415190.08
# PABELLÓN                                                                                  NaN
#
#                                              46-VÍVERES
# Centro de Costo
# 66-HOSPITALIZACIÓN MEDICINA INTERNA                 NaN
# 90-HOSPITALIZACIÓN QUIRÚRGICA                       NaN
# 102-HOSPITALIZACIÓN CARDIOVASCULAR                  NaN
# 464-QUIRÓFANOS CARDIOVASCULAR                       NaN
# 484-QUIRÓFANOS TORACICA                             NaN
# 166-UNIDAD DE CUIDADOS INTENSIVOS                   NaN
# 195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO          NaN
# 15105-CONSULTA CARDIOLOGÍA                          NaN
# 15107-CONSULTA ONCOLOGÍA                            NaN
# 15111-CONSULTA NEUMOLOGÍA                           NaN
# 15123-PROGRAMA MANEJO DEL DOLOR                     NaN
# 15201-CONSULTA CIRUGÍA GENERAL                      NaN
# 15220-CONSULTA CIRUGIA CARDIACA                     NaN
# 15008-CONSULTA NUTRICIÓN                            NaN
# 15010-CONSULTA OTROS PROFESIONALES                  NaN
# 631-CENTRO DE COSTOS EXTERNO                        NaN
# 15022-PROCEDIMIENTO DE NEUMOLOGÍA                   NaN
# 245-PROCEDIMIENTOS ASISTENCIA VENTRICULAR           NaN
# 15026-PROCEDIMIENTOS DE CARDIOLOGÍA                 NaN
# 253-PROCEDIMIENTOS DE HEMODINAMIA                   NaN
# 15038-PROCEDIMIENTO ONCOLOGÍA                       NaN
# 262-PROCEDIMIENTOS DE TRAUMATOLOGÍA                 NaN
# 264-PROCEDIMIENTOS EBUS                             NaN
# 265-PROCEDIMIENTOS ECMO                             NaN
# 267-PROCEDIMIENTOS ENDOSCÓPICOS                     NaN
# 270-PROCEDIMIENTOS TAVI                             NaN
# 518-LABORATORIO CLÍNICO                             NaN
# 537-ECOCARDIOGRAFÍA                                 NaN
# 41107-TOMOGRAFÍA                                    NaN
# 41108-IMAGENOLOGÍA                                  NaN
# 544-ANATOMÍA PATOLÓGICA                             NaN
# 51001-BANCO DE SANGRE                               NaN
# 55101-SERVICIO FARMACEUTICO                         NaN
# 95301-CENTRAL DE ESTERILIZACIÓN                     NaN
# 652-SERVICIO DE ALIMENTACIÓN                23753900.93
# 95501-MANTENIMIENTO                                 NaN
# 670-ADMINISTRACIÓN                            109283.06
# PABELLÓN                                            NaN

# %%
diccionario_todos_los_desgloses = {
    '41108-IMAGENOLOGÍA': ['41107-TOMOGRAFÍA', '41108-IMAGENOLOGÍA'],
    'PABELLÓN': ['464-QUIRÓFANOS CARDIOVASCULAR', '484-QUIRÓFANOS TORACICA'],
    '518-LABORATORIO CLÍNICO': ['51001-BANCO DE SANGRE', '518-LABORATORIO CLÍNICO'],
    '66-HOSPITALIZACIÓN MEDICINA INTERNA': ['90-HOSPITALIZACIÓN QUIRÚRGICA', '66-HOSPITALIZACIÓN MEDICINA INTERNA'],
    '253-PROCEDIMIENTOS DE HEMODINAMIA': ['270-PROCEDIMIENTOS TAVI', '264-PROCEDIMIENTOS EBUS', 
                                          '15022-PROCEDIMIENTO DE NEUMOLOGÍA', 
                                          '253-PROCEDIMIENTOS DE HEMODINAMIA'],
    '15026-PROCEDIMIENTOS DE CARDIOLOGÍA': ['15105-CONSULTA CARDIOLOGÍA', '265-PROCEDIMIENTOS ECMO',
                                           '15220-CONSULTA CIRUGIA CARDIACA', '15201-CONSULTA CIRUGÍA GENERAL',
                                           '15026-PROCEDIMIENTOS DE CARDIOLOGÍA'],
    '166-UNIDAD DE CUIDADOS INTENSIVOS': ['195-UNIDAD DE TRATAMIENTO INTENSIVO ADULTO', 
                                          '166-UNIDAD DE CUIDADOS INTENSIVOS'],
    '15038-PROCEDIMIENTO ONCOLOGÍA': ['15123-PROGRAMA MANEJO DEL DOLOR',
                                      '15107-CONSULTA ONCOLOGÍA',
                                      '15038-PROCEDIMIENTO ONCOLOGÍA'],
    '670-ADMINISTRACIÓN': ['15008-CONSULTA NUTRICIÓN', '670-ADMINISTRACIÓN']
    
}

# %%
total = pd.DataFrame()
for item_desglose in diccionario_todos_los_desgloses:
    if item_desglose in tabla_din.index:
        filas_a_agregar = []
        a_desglosar = diccionario_todos_los_desgloses[item_desglose]
        valores_antiguos = tabla_din.loc[item_desglose]
        for desglose in a_desglosar:
            print(f'El item {item_desglose} lo estamos desglosando en {desglose}')
            porcentaje = input('¿Qué porcentaje tiene este item?: ')
            porcentaje = float(porcentaje)
            porcentaje_cantidad = valores_antiguos * porcentaje
            porcentaje_cantidad.name = desglose

            filas_a_agregar.append(porcentaje_cantidad)
    
        valores_antiguos.name = 'Total'
        filas_a_agregar.append(valores_antiguos)
        df_super = pd.DataFrame(filas_a_agregar)
    
    else:
        print('No hubo gastos en este item.')
    
    total = pd.concat([total, df_super])
# Out:
# El item 41108-IMAGENOLOGÍA lo estamos desglosando en 41107-TOMOGRAFÍA
# El item 41108-IMAGENOLOGÍA lo estamos desglosando en 41108-IMAGENOLOGÍA
# El item PABELLÓN lo estamos desglosando en 464-QUIRÓFANOS CARDIOVASCULAR
# El item PABELLÓN lo estamos desglosando en 484-QUIRÓFANOS TORACICA
# El item 518-LABORATORIO CLÍNICO lo estamos desglosando en 51001-BANCO DE SANGRE
# El item 518-LABORATORIO CLÍNICO lo estamos desglosando en 518-LABORATORIO CLÍNICO
# El item 66-HOSPITALIZACIÓN MEDICINA INTERNA lo estamos desglosando en 90-HOSPITALIZACIÓN QUIRÚRGICA
# El item 66-HOSPITALIZACIÓN MEDICINA INTERNA lo estamos desglosando en 66-HOSPITALIZACIÓN MEDICINA INTERNA
# El item 253-PROCEDIMIENTOS DE HEMODINAMIA lo estamos desglosando en 270-PROCEDIMIENTOS TAVI
# El item 253-PROCEDIMIENTOS DE HEMODINAMIA lo estamos desglosando en 264-PROCEDIMIENTOS EBUS
# El item 253-PROCEDIMIENTOS DE HEMODINAMIA lo estamos desglosando en 15022-PROCEDIMIENTO DE NEUMOLOGÍA
# El item 253-PROCEDIMIENTOS DE HEMODINAMIA lo estamos desglosando en 253-PROCEDIMIENTOS DE HEMODINAMIA
# El item 15026-PROCEDIMIENTOS DE CARDIOLOGÍA lo estamos desglosando en 15105-CONSULTA CARDIOLOGÍA
# El item 15026-PROCEDIMIENTOS DE CARDIOLOGÍA lo estamos desglosando en 265-PROCEDIMIENTOS ECMO
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\gmolina\Desktop\Javier\INT\finanzas\planilla_centro_de_costos_sigcom\SEPTIEMBRE_2022\suministros\analisis_suministros.ipynb Celda 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/Javier/INT/finanzas/planilla_centro_de_costos_sigcom/SEPTIEMBRE_2022/suministros/analisis_suministros.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> print(f'El item {item_desglose} lo estamos desglosando en {desglose}')
#       <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/Javier/INT/finanzas/planilla_centro_de_costos_sigcom/SEPTIEMBRE_2022/suministros/analisis_suministros.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> porcentaje = input('¿Qué porcentaje tiene este item?: ')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/Javier/INT/finanzas/planilla_centro_de_costos_sigcom/SEPTIEMBRE_2022/suministros/analisis_suministros.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> porcentaje = float(porcentaje)
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/Javier/INT/finanzas/planilla_centro_de_costos_sigcom/SEPTIEMBRE_2022/suministros/analisis_suministros.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> porcentaje_cantidad = valores_antiguos * porcentaje
#      <a href='vscode-notebook-cell:/c%3A/Users/gmolina/Desktop/Javier/INT/finanzas/planilla_centro_de_costos_sigcom/SEPTIEMBRE_2022/suministros/analisis_suministros.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> porcentaje_cantidad.name = desglose
#
# ValueError: could not convert string to float: ''
