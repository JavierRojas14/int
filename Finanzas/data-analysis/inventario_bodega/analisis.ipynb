# %%
import pandas as pd

# %%
df = pd.read_excel('LISTADO INVENTARIO BODEGA.xlsx')

# %%
df
# Out:
#        CODIGO                         NOMBRE ARTICULO  STOCK     SERIE   \
# 0     A006300                     ALCOHOL 70º 1 LITRO     24  SIN SERIE
# 1     A006700  AMONIO CUATERNARIO 2,5% QUICK FILL 920      1  SIN SERIE
# 2     A031900                       ALCOHOL 70º 250CC    245  SIN SERIE
# 3     A032200  SOLUCION CLORHEX. JABONOSA 2% FCO 1 LT    144  SIN SERIE
# 4     A032200  SOLUCION CLORHEX. JABONOSA 2% FCO 1 LT     74  SIN SERIE
# ...       ...                                     ...    ...        ...
# 1835  Z174800           GRAPADORA LINEAL GIA 80-4.8MM     17  SIN SERIE
# 1836  Z174800           GRAPADORA LINEAL GIA 80-4.8MM     15  SIN SERIE
# 1837  Z174900              CARGA LINEAL GIA 80-4.8 MM     11  SIN SERIE
# 1838  Z930100         TROCAR VTC (THORACOPORE) # 10.5     12  SIN SERIE
# 1839  Z930200                       TROCAR VTC Nº 5.5     12  SIN SERIE
#
#             LOTE    FECHA VENCIMIENTO
# 0     4030226220  2024-03-31 23:00:00
# ...

# %%
df.info()
