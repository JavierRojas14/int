# %%
import pandas as pd
import os

# %%
nombres_sensibilidades_ordenadas = sorted([excel for excel in os.listdir() if 'SENS' in excel], key = lambda x: int(x[0:2]))
dfs = {}
for nombre in nombres_sensibilidades_ordenadas:
    df = pd.read_excel(nombre, sheet_name = 1, header = 1)
    dfs[nombre] = df

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Lab Bateriologia\MICROBIOLOGÍA\A.MICROBIOLOGIA\Sens\2022\estadisticas.ipynb Celda 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell://10.5.167.202/Lab%20Bateriologia/MICROBIOLOG%C3%8DA/A.MICROBIOLOGIA/Sens/2022/estadisticas.ipynb#ch0000001?line=1'>2</a> dfs = {}
#       <a href='vscode-notebook-cell://10.5.167.202/Lab%20Bateriologia/MICROBIOLOG%C3%8DA/A.MICROBIOLOGIA/Sens/2022/estadisticas.ipynb#ch0000001?line=2'>3</a> for nombre in nombres_sensibilidades_ordenadas:
# ----> <a href='vscode-notebook-cell://10.5.167.202/Lab%20Bateriologia/MICROBIOLOG%C3%8DA/A.MICROBIOLOGIA/Sens/2022/estadisticas.ipynb#ch0000001?line=3'>4</a>     df = pd.read_excel(nombre, sheet_name = 1, header = 1)
# ...

# %%
df = pd.read_excel('1 SENS_ ENERO 22.xlsx', sheet_name = 1, header = 1)

# %%
df
# Out:
#     Unnamed: 0           Unnamed: 1          Unnamed: 2 Unnamed: 3  \
# 0           N°      FECHA RECEPCION        TIPO MUESTRA     NºCEPA
# 1            1  2022-01-01 00:00:00                HEMO       1: I
# 2            2  2022-01-01 00:00:00  HEMO: ARRASTRE CVC     1: III
# 3            3  2022-01-01 00:00:00                 S.T     917028
# 4            4  2022-01-01 00:00:00                 S.T     917028
# ..         ...                  ...                 ...        ...
# 272        272  2022-01-31 00:00:00                 EXP     923191
# 273        273  2022-01-31 00:00:00                 EXP     923191
# 274        274  2022-01-31 00:00:00                 EXP     923191
# 275        275  2022-01-31 00:00:00        ESTERNOTOMIA     923225
# 276        276  2022-01-31 00:00:00        ESTERNOTOMIA     923225
#
#        Unnamed: 4                      Unnamed: 5      Unnamed: 6  Unnamed: 7  \
# 0             RUT                 NOMBRE PACIENTE        SERVICIO  COMENTARIO
# ...
